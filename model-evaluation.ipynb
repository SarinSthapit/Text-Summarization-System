# %% [markdown]
# # **Text Summarization System**
#
# **Neural Network and Deep Learning (COMP 488)**
#
# **Mini Project**

# %%
# !pip install openpyxl  --quiet

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
import string
import tensorflow as tf
import re
import os
import time
from tensorflow import keras
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
references=["New trailer of  Justice League  released",
            "Underprivileged kids to fill Wankhede during MI s IPL match  ",
           "UP govt assures transparent system to end cheating in exams  ",
           "Ashwin breaks record for most wickets in a Test season"]
generated=["new trailer of justice league released",
           "underprivileged kids to present in wankhede stadium",
          " up govt govt assures transparent system to end cheating in exams",
          "Ashwin breaks record for most wickets in a test season"]

# %%
reference_words_per_sentence = [reference.split() for reference in references]
generated_words_per_sentence = [sentence.split() for sentence in generated]

# %%
from rouge import Rouge

# Create a Rouge object
rouge = Rouge()

# Calculate ROUGE scores
scores = rouge.get_scores(generated, references)

# Print ROUGE scores
print("ROUGE Scores:")
print(f"ROUGE-N (Unigram): Precision = {scores[0]['rouge-1']['p']}, Recall = {scores[0]['rouge-1']['r']}, F1 = {scores[0]['rouge-1']['f']}")
print(f"ROUGE-L: Precision = {scores[0]['rouge-l']['p']}, Recall = {scores[0]['rouge-l']['r']}, F1 = {scores[0]['rouge-l']['f']}")
# Out:
# ROUGE Scores:
# ROUGE-N (Unigram): Precision = 0.5, Recall = 0.5, F1 = 0.4999999950000001
# ROUGE-L: Precision = 0.5, Recall = 0.5, F1 = 0.4999999950000001

# %%
# !pip install -U nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
from nltk.translate.bleu_score import corpus_bleu



# Calculate BLEU score
bleu_score = corpus_bleu(reference_words_per_sentence, generated_words_per_sentence)

# Print BLEU score
print(f"BLEU Score: {bleu_score:.4f}")
# Out:
# BLEU Score: 0.4141
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
ENCODER_LEN = 100
DECODER_LEN = 20
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE * 8

# %%
news = pd.read_excel("/kaggle/input/cnn-dailymail/data.xlsx",engine = 'openpyxl')
news.head()
# Out:
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
#
#                                                Short
# 0  The CBI on Saturday booked four former officia...
# 1  Chief Justice JS Khehar has said the Supreme C...
# 2  At least three people were killed, including a...
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4  TV news anchor Arnab Goswami has said he was t...

# %%
news.shape
# Out:
# (55104, 2)

# %%
article = news['Short']
summary = news['Headline']
article = article.apply(lambda x: '<SOS> ' + x + ' <EOS>')
summary = summary.apply(lambda x: '<SOS> ' + x + ' <EOS>')

# %%
def preprocess(text):
    text = re.sub(r"&.[1-9]+;"," ",text)
    return text

article = article.apply(lambda x: preprocess(x))
summary = summary.apply(lambda x: preprocess(x))

# %%
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'
article_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)
article_tokenizer.fit_on_texts(article)
summary_tokenizer.fit_on_texts(summary)
inputs = article_tokenizer.texts_to_sequences(article)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
ENCODER_VOCAB = len(article_tokenizer.word_index) + 1
DECODER_VOCAB = len(summary_tokenizer.word_index) + 1
print(ENCODER_VOCAB, DECODER_VOCAB)
# Out:
# 76362 29661

# %%
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs = tf.cast(inputs, dtype=tf.int64)
targets = tf.cast(targets, dtype=tf.int64)

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def get_dataset_partitions(ds, ds_size, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    if shuffle:
        # Specify seed to always have the same split distribution between runs
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_dataset,validation_dataset,test_dataset=get_dataset_partitions(dataset,dataset.cardinality().numpy())

# %%
train_dataset
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 100), dtype=tf.int64, name=None), TensorSpec(shape=(None, 20), dtype=tf.int64, name=None))>

# %%
def calculate_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

# %%
def generate_positional_encoding(position, d_model):
    angle_rads = calculate_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def generate_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

# %%
def generate_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

# %%
def compute_scaled_dot_product(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = compute_scaled_dot_product(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

# %%
def built_pointwise_feedforward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = built_pointwise_feedforward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = built_pointwise_feedforward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = generate_positional_encoding(maximum_position_encoding, self.d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x

class Decoder(tf.keras.layers.Layer):

    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = generate_positional_encoding(maximum_position_encoding, d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training, look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        enc_output = self.encoder(inp, training, enc_padding_mask)

        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
num_layers = 3
d_model = 128
dff = 512
num_heads = 4
dropout_rate = 0.2
EPOCHS = 500

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return (tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2))

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
temp_learning_rate_schedule = CustomSchedule(d_model)

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    #accuracies = tf.cast(accuracies, dtype= tf.float32)

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
val_loss = tf.keras.metrics.Mean(name='train_loss')
val_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=ENCODER_VOCAB,
    target_vocab_size=DECODER_VOCAB,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
def generate_masks(inp, tar):
    enc_padding_mask = generate_padding_mask(inp)
    dec_padding_mask = generate_padding_mask(inp)

    look_ahead_mask = generate_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = generate_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(
            inp, tar_inp,
            True,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

# %%
@tf.function
def val_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(inp, tar_inp)

    predictions, _ = transformer(
        inp, tar_inp,
        False,  # Inference mode for validation
        enc_padding_mask,
        combined_mask,
        dec_padding_mask
    )
    loss = loss_function(tar_real, predictions)

    val_loss(loss)
    val_accuracy(accuracy_function(tar_real, predictions))

# %%
train_loss_values=[]
train_accuracy_values=[]
val_loss_values=[]
val_accuracy_values=[]

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()

    for (batch, (inp, tar)) in enumerate(train_dataset):
        train_step(inp, tar)

        if batch % 100 == 0:
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1, ckpt_save_path))

    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
    train_loss_values.append(train_loss.result())
    train_accuracy_values.append(train_accuracy.result())

    for (batch, (inp, tar)) in enumerate(validation_dataset):
        val_step(inp, tar)

    # After each epoch, print or use the validation metrics
    print(f'Validation Loss: {val_loss.result():.4f} Validation Accuracy: {val_accuracy.result():.4f}')
    val_loss_values.append(val_loss.result())
    val_accuracy_values.append(val_accuracy.result())
    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 10.2904 Accuracy 0.0000
# Epoch 1 Batch 100 Loss 10.2034 Accuracy 0.0621
# Epoch 1 Batch 200 Loss 9.9912 Accuracy 0.0832
# Epoch 1 Batch 300 Loss 9.6931 Accuracy 0.0898
# Epoch 1 Batch 400 Loss 9.3518 Accuracy 0.0932
# Epoch 1 Batch 500 Loss 9.0357 Accuracy 0.0955
# Epoch 1 Batch 600 Loss 8.7912 Accuracy 0.0972
# Epoch 1 Loss 8.6264 Accuracy 0.1005
# Validation Loss: 7.3840 Validation Accuracy: 0.1214
# Time taken for 1 epoch: 142.9524371623993 secs
#
# Epoch 2 Batch 0 Loss 7.2232 Accuracy 0.1006
# Epoch 2 Batch 100 Loss 7.3488 Accuracy 0.1036
# Epoch 2 Batch 200 Loss 7.3183 Accuracy 0.1064
# Epoch 2 Batch 300 Loss 7.2857 Accuracy 0.1097
# Epoch 2 Batch 400 Loss 7.2570 Accuracy 0.1124
# Epoch 2 Batch 500 Loss 7.2239 Accuracy 0.1151
# Epoch 2 Batch 600 Loss 7.1933 Accuracy 0.1171
# Epoch 2 Loss 7.1638 Accuracy 0.1189
# Validation Loss: 7.0685 Validation Accuracy: 0.1362
# Time taken for 1 epoch: 75.03481602668762 secs
#
# Epoch 3 Batch 0 Loss 6.5717 Accuracy 0.1189
# Epoch 3 Batch 100 Loss 6.7673 Accuracy 0.1209
# Epoch 3 Batch 200 Loss 6.7407 Accuracy 0.1230
# Epoch 3 Batch 300 Loss 6.7166 Accuracy 0.1250
# Epoch 3 Batch 400 Loss 6.7021 Accuracy 0.1268
# Epoch 3 Batch 500 Loss 6.6792 Accuracy 0.1285
# Epoch 3 Batch 600 Loss 6.6536 Accuracy 0.1303
# Epoch 3 Loss 6.6271 Accuracy 0.1320
# Validation Loss: 6.7765 Validation Accuracy: 0.1493
# Time taken for 1 epoch: 73.26359581947327 secs
#
# Epoch 4 Batch 0 Loss 6.4063 Accuracy 0.1320
# Epoch 4 Batch 100 Loss 6.2300 Accuracy 0.1338
# Epoch 4 Batch 200 Loss 6.2157 Accuracy 0.1359
# Epoch 4 Batch 300 Loss 6.2025 Accuracy 0.1377
# Epoch 4 Batch 400 Loss 6.1941 Accuracy 0.1396
# Epoch 4 Batch 500 Loss 6.1762 Accuracy 0.1414
# Epoch 4 Batch 600 Loss 6.1592 Accuracy 0.1433
# Epoch 4 Loss 6.1478 Accuracy 0.1448
# Validation Loss: 6.5113 Validation Accuracy: 0.1631
# Time taken for 1 epoch: 73.27460598945618 secs
#
# Epoch 5 Batch 0 Loss 5.7480 Accuracy 0.1448
# Epoch 5 Batch 100 Loss 5.7682 Accuracy 0.1469
# Epoch 5 Batch 200 Loss 5.7664 Accuracy 0.1489
# Epoch 5 Batch 300 Loss 5.7558 Accuracy 0.1509
# Epoch 5 Batch 400 Loss 5.7523 Accuracy 0.1527
# Epoch 5 Batch 500 Loss 5.7456 Accuracy 0.1546
# Epoch 5 Batch 600 Loss 5.7392 Accuracy 0.1565
# Saving checkpoint for epoch 5 at checkpoints/ckpt-1
# Epoch 5 Loss 5.7368 Accuracy 0.1580
# Validation Loss: 6.2495 Validation Accuracy: 0.1803
# Time taken for 1 epoch: 73.3456540107727 secs
#
# Epoch 6 Batch 0 Loss 5.1619 Accuracy 0.1581
# Epoch 6 Batch 100 Loss 5.3685 Accuracy 0.1602
# Epoch 6 Batch 200 Loss 5.3605 Accuracy 0.1624
# Epoch 6 Batch 300 Loss 5.3611 Accuracy 0.1645
# Epoch 6 Batch 400 Loss 5.3730 Accuracy 0.1664
# Epoch 6 Batch 500 Loss 5.3756 Accuracy 0.1683
# Epoch 6 Batch 600 Loss 5.3828 Accuracy 0.1701
# Epoch 6 Loss 5.3754 Accuracy 0.1717
# Validation Loss: 5.9976 Validation Accuracy: 0.1979
# Time taken for 1 epoch: 72.30419373512268 secs
#
# Epoch 7 Batch 0 Loss 5.1787 Accuracy 0.1717
# Epoch 7 Batch 100 Loss 4.9641 Accuracy 0.1740
# Epoch 7 Batch 200 Loss 4.9856 Accuracy 0.1762
# Epoch 7 Batch 300 Loss 4.9943 Accuracy 0.1783
# Epoch 7 Batch 400 Loss 5.0035 Accuracy 0.1804
# Epoch 7 Batch 500 Loss 5.0146 Accuracy 0.1822
# Epoch 7 Batch 600 Loss 5.0162 Accuracy 0.1842
# Epoch 7 Loss 5.0179 Accuracy 0.1858
# Validation Loss: 5.7588 Validation Accuracy: 0.2167
# Time taken for 1 epoch: 71.34229564666748 secs
#
# Epoch 8 Batch 0 Loss 4.0348 Accuracy 0.1859
# Epoch 8 Batch 100 Loss 4.5998 Accuracy 0.1883
# Epoch 8 Batch 200 Loss 4.6258 Accuracy 0.1905
# Epoch 8 Batch 300 Loss 4.6474 Accuracy 0.1926
# Epoch 8 Batch 400 Loss 4.6628 Accuracy 0.1947
# Epoch 8 Batch 500 Loss 4.6748 Accuracy 0.1966
# Epoch 8 Batch 600 Loss 4.6793 Accuracy 0.1986
# Epoch 8 Loss 4.6877 Accuracy 0.2002
# Validation Loss: 5.5351 Validation Accuracy: 0.2355
# Time taken for 1 epoch: 71.6659779548645 secs
#
# Epoch 9 Batch 0 Loss 4.4406 Accuracy 0.2003
# Epoch 9 Batch 100 Loss 4.3057 Accuracy 0.2025
# Epoch 9 Batch 200 Loss 4.3169 Accuracy 0.2048
# Epoch 9 Batch 300 Loss 4.3555 Accuracy 0.2068
# Epoch 9 Batch 400 Loss 4.3678 Accuracy 0.2088
# Epoch 9 Batch 500 Loss 4.3854 Accuracy 0.2107
# Epoch 9 Batch 600 Loss 4.3969 Accuracy 0.2126
# Epoch 9 Loss 4.4069 Accuracy 0.2143
# Validation Loss: 5.3250 Validation Accuracy: 0.2547
# Time taken for 1 epoch: 71.59463167190552 secs
#
# Epoch 10 Batch 0 Loss 4.0105 Accuracy 0.2143
# Epoch 10 Batch 100 Loss 4.0160 Accuracy 0.2167
# Epoch 10 Batch 200 Loss 4.0578 Accuracy 0.2189
# Epoch 10 Batch 300 Loss 4.1060 Accuracy 0.2209
# Epoch 10 Batch 400 Loss 4.1373 Accuracy 0.2228
# Epoch 10 Batch 500 Loss 4.1481 Accuracy 0.2248
# Epoch 10 Batch 600 Loss 4.1656 Accuracy 0.2266
# Saving checkpoint for epoch 10 at checkpoints/ckpt-2
# Epoch 10 Loss 4.1796 Accuracy 0.2281
# Validation Loss: 5.1324 Validation Accuracy: 0.2732
# Time taken for 1 epoch: 72.13045740127563 secs
#
# Epoch 11 Batch 0 Loss 3.8402 Accuracy 0.2281
# Epoch 11 Batch 100 Loss 3.7945 Accuracy 0.2304
# Epoch 11 Batch 200 Loss 3.8380 Accuracy 0.2325
# Epoch 11 Batch 300 Loss 3.8706 Accuracy 0.2346
# Epoch 11 Batch 400 Loss 3.9168 Accuracy 0.2364
# Epoch 11 Batch 500 Loss 3.9411 Accuracy 0.2382
# Epoch 11 Batch 600 Loss 3.9615 Accuracy 0.2399
# Epoch 11 Loss 3.9853 Accuracy 0.2414
# Validation Loss: 4.9585 Validation Accuracy: 0.2906
# Time taken for 1 epoch: 71.63681936264038 secs
#
# Epoch 12 Batch 0 Loss 3.5064 Accuracy 0.2414
# Epoch 12 Batch 100 Loss 3.6436 Accuracy 0.2435
# Epoch 12 Batch 200 Loss 3.6837 Accuracy 0.2455
# Epoch 12 Batch 300 Loss 3.7213 Accuracy 0.2474
# Epoch 12 Batch 400 Loss 3.7528 Accuracy 0.2492
# Epoch 12 Batch 500 Loss 3.7835 Accuracy 0.2510
# Epoch 12 Batch 600 Loss 3.8073 Accuracy 0.2526
# Epoch 12 Loss 3.8291 Accuracy 0.2540
# Validation Loss: 4.7986 Validation Accuracy: 0.3076
# Time taken for 1 epoch: 71.58470010757446 secs
#
# Epoch 13 Batch 0 Loss 3.2531 Accuracy 0.2541
# Epoch 13 Batch 100 Loss 3.5286 Accuracy 0.2561
# Epoch 13 Batch 200 Loss 3.5608 Accuracy 0.2580
# Epoch 13 Batch 300 Loss 3.5962 Accuracy 0.2598
# Epoch 13 Batch 400 Loss 3.6151 Accuracy 0.2616
# Epoch 13 Batch 500 Loss 3.6399 Accuracy 0.2633
# Epoch 13 Batch 600 Loss 3.6663 Accuracy 0.2649
# Epoch 13 Loss 3.6870 Accuracy 0.2663
# Validation Loss: 4.6534 Validation Accuracy: 0.3232
# Time taken for 1 epoch: 71.23000979423523 secs
#
# Epoch 14 Batch 0 Loss 3.7276 Accuracy 0.2663
# Epoch 14 Batch 100 Loss 3.3983 Accuracy 0.2683
# Epoch 14 Batch 200 Loss 3.4191 Accuracy 0.2702
# Epoch 14 Batch 300 Loss 3.4614 Accuracy 0.2719
# Epoch 14 Batch 400 Loss 3.4882 Accuracy 0.2735
# Epoch 14 Batch 500 Loss 3.5244 Accuracy 0.2751
# Epoch 14 Batch 600 Loss 3.5467 Accuracy 0.2767
# Epoch 14 Loss 3.5675 Accuracy 0.2780
# Validation Loss: 4.5208 Validation Accuracy: 0.3379
# Time taken for 1 epoch: 71.41153836250305 secs
#
# Epoch 15 Batch 0 Loss 3.0195 Accuracy 0.2780
# Epoch 15 Batch 100 Loss 3.2499 Accuracy 0.2799
# Epoch 15 Batch 200 Loss 3.3126 Accuracy 0.2817
# Epoch 15 Batch 300 Loss 3.3532 Accuracy 0.2833
# Epoch 15 Batch 400 Loss 3.3849 Accuracy 0.2849
# Epoch 15 Batch 500 Loss 3.4115 Accuracy 0.2865
# Epoch 15 Batch 600 Loss 3.4400 Accuracy 0.2879
# Saving checkpoint for epoch 15 at checkpoints/ckpt-3
# Epoch 15 Loss 3.4600 Accuracy 0.2891
# Validation Loss: 4.3984 Validation Accuracy: 0.3519
# Time taken for 1 epoch: 72.25204396247864 secs
#
# Epoch 16 Batch 0 Loss 2.9501 Accuracy 0.2892
# Epoch 16 Batch 100 Loss 3.1436 Accuracy 0.2910
# Epoch 16 Batch 200 Loss 3.1763 Accuracy 0.2927
# Epoch 16 Batch 300 Loss 3.2287 Accuracy 0.2942
# Epoch 16 Batch 400 Loss 3.2618 Accuracy 0.2958
# Epoch 16 Batch 500 Loss 3.2972 Accuracy 0.2972
# Epoch 16 Batch 600 Loss 3.3247 Accuracy 0.2986
# Epoch 16 Loss 3.3475 Accuracy 0.2998
# Validation Loss: 4.2793 Validation Accuracy: 0.3660
# Time taken for 1 epoch: 71.65041303634644 secs
#
# Epoch 17 Batch 0 Loss 3.4407 Accuracy 0.2998
# Epoch 17 Batch 100 Loss 3.0705 Accuracy 0.3015
# Epoch 17 Batch 200 Loss 3.0918 Accuracy 0.3031
# Epoch 17 Batch 300 Loss 3.1258 Accuracy 0.3046
# Epoch 17 Batch 400 Loss 3.1600 Accuracy 0.3061
# Epoch 17 Batch 500 Loss 3.1870 Accuracy 0.3075
# Epoch 17 Batch 600 Loss 3.2135 Accuracy 0.3089
# Epoch 17 Loss 3.2345 Accuracy 0.3100
# Validation Loss: 4.1695 Validation Accuracy: 0.3791
# Time taken for 1 epoch: 71.64735317230225 secs
#
# Epoch 18 Batch 0 Loss 2.7542 Accuracy 0.3100
# Epoch 18 Batch 100 Loss 2.9104 Accuracy 0.3117
# Epoch 18 Batch 200 Loss 2.9664 Accuracy 0.3132
# Epoch 18 Batch 300 Loss 3.0008 Accuracy 0.3147
# Epoch 18 Batch 400 Loss 3.0480 Accuracy 0.3161
# Epoch 18 Batch 500 Loss 3.0818 Accuracy 0.3175
# Epoch 18 Batch 600 Loss 3.1114 Accuracy 0.3187
# Epoch 18 Loss 3.1389 Accuracy 0.3198
# Validation Loss: 4.0653 Validation Accuracy: 0.3916
# Time taken for 1 epoch: 71.59861207008362 secs
#
# Epoch 19 Batch 0 Loss 2.5483 Accuracy 0.3199
# Epoch 19 Batch 100 Loss 2.8417 Accuracy 0.3214
# Epoch 19 Batch 200 Loss 2.8939 Accuracy 0.3229
# Epoch 19 Batch 300 Loss 2.9429 Accuracy 0.3243
# Epoch 19 Batch 400 Loss 2.9646 Accuracy 0.3257
# Epoch 19 Batch 500 Loss 2.9981 Accuracy 0.3269
# Epoch 19 Batch 600 Loss 3.0206 Accuracy 0.3282
# Epoch 19 Loss 3.0443 Accuracy 0.3293
# Validation Loss: 3.9660 Validation Accuracy: 0.4038
# Time taken for 1 epoch: 71.16262888908386 secs
#
# Epoch 20 Batch 0 Loss 2.4863 Accuracy 0.3293
# Epoch 20 Batch 100 Loss 2.7370 Accuracy 0.3308
# Epoch 20 Batch 200 Loss 2.7683 Accuracy 0.3323
# Epoch 20 Batch 300 Loss 2.8146 Accuracy 0.3337
# Epoch 20 Batch 400 Loss 2.8614 Accuracy 0.3350
# Epoch 20 Batch 500 Loss 2.8938 Accuracy 0.3362
# Epoch 20 Batch 600 Loss 2.9305 Accuracy 0.3374
# Saving checkpoint for epoch 20 at checkpoints/ckpt-4
# Epoch 20 Loss 2.9560 Accuracy 0.3384
# Validation Loss: 3.8730 Validation Accuracy: 0.4155
# Time taken for 1 epoch: 72.02744579315186 secs
#
# Epoch 21 Batch 0 Loss 2.8756 Accuracy 0.3384
# Epoch 21 Batch 100 Loss 2.6785 Accuracy 0.3399
# Epoch 21 Batch 200 Loss 2.7296 Accuracy 0.3412
# Epoch 21 Batch 300 Loss 2.7538 Accuracy 0.3426
# Epoch 21 Batch 400 Loss 2.7901 Accuracy 0.3439
# Epoch 21 Batch 500 Loss 2.8245 Accuracy 0.3451
# Epoch 21 Batch 600 Loss 2.8518 Accuracy 0.3462
# Epoch 21 Loss 2.8746 Accuracy 0.3472
# Validation Loss: 3.7861 Validation Accuracy: 0.4266
# Time taken for 1 epoch: 71.32355332374573 secs
#
# Epoch 22 Batch 0 Loss 2.7336 Accuracy 0.3473
# Epoch 22 Batch 100 Loss 2.5831 Accuracy 0.3487
# Epoch 22 Batch 200 Loss 2.6270 Accuracy 0.3500
# Epoch 22 Batch 300 Loss 2.6665 Accuracy 0.3513
# Epoch 22 Batch 400 Loss 2.7047 Accuracy 0.3525
# Epoch 22 Batch 500 Loss 2.7463 Accuracy 0.3536
# Epoch 22 Batch 600 Loss 2.7809 Accuracy 0.3547
# Epoch 22 Loss 2.8065 Accuracy 0.3556
# Validation Loss: 3.7019 Validation Accuracy: 0.4372
# Time taken for 1 epoch: 71.35168862342834 secs
#
# Epoch 23 Batch 0 Loss 2.9923 Accuracy 0.3556
# Epoch 23 Batch 100 Loss 2.5403 Accuracy 0.3570
# Epoch 23 Batch 200 Loss 2.5765 Accuracy 0.3583
# Epoch 23 Batch 300 Loss 2.6181 Accuracy 0.3595
# Epoch 23 Batch 400 Loss 2.6505 Accuracy 0.3606
# Epoch 23 Batch 500 Loss 2.6858 Accuracy 0.3617
# Epoch 23 Batch 600 Loss 2.7201 Accuracy 0.3628
# Epoch 23 Loss 2.7445 Accuracy 0.3637
# Validation Loss: 3.6239 Validation Accuracy: 0.4472
# Time taken for 1 epoch: 71.44562554359436 secs
#
# Epoch 24 Batch 0 Loss 2.1612 Accuracy 0.3637
# Epoch 24 Batch 100 Loss 2.4655 Accuracy 0.3650
# Epoch 24 Batch 200 Loss 2.4936 Accuracy 0.3663
# Epoch 24 Batch 300 Loss 2.5424 Accuracy 0.3675
# Epoch 24 Batch 400 Loss 2.5823 Accuracy 0.3685
# Epoch 24 Batch 500 Loss 2.6223 Accuracy 0.3696
# Epoch 24 Batch 600 Loss 2.6507 Accuracy 0.3706
# Epoch 24 Loss 2.6722 Accuracy 0.3715
# Validation Loss: 3.5480 Validation Accuracy: 0.4571
# Time taken for 1 epoch: 71.47366333007812 secs
#
# Epoch 25 Batch 0 Loss 2.1689 Accuracy 0.3715
# Epoch 25 Batch 100 Loss 2.3943 Accuracy 0.3728
# Epoch 25 Batch 200 Loss 2.4417 Accuracy 0.3740
# Epoch 25 Batch 300 Loss 2.4847 Accuracy 0.3751
# Epoch 25 Batch 400 Loss 2.5162 Accuracy 0.3762
# Epoch 25 Batch 500 Loss 2.5523 Accuracy 0.3772
# Epoch 25 Batch 600 Loss 2.5870 Accuracy 0.3782
# Saving checkpoint for epoch 25 at checkpoints/ckpt-5
# Epoch 25 Loss 2.6185 Accuracy 0.3790
# Validation Loss: 3.4776 Validation Accuracy: 0.4662
# Time taken for 1 epoch: 72.08159160614014 secs
#
# Epoch 26 Batch 0 Loss 2.0863 Accuracy 0.3791
# Epoch 26 Batch 100 Loss 2.3421 Accuracy 0.3803
# Epoch 26 Batch 200 Loss 2.3817 Accuracy 0.3814
# Epoch 26 Batch 300 Loss 2.4199 Accuracy 0.3825
# Epoch 26 Batch 400 Loss 2.4631 Accuracy 0.3835
# Epoch 26 Batch 500 Loss 2.4954 Accuracy 0.3845
# Epoch 26 Batch 600 Loss 2.5256 Accuracy 0.3855
# Epoch 26 Loss 2.5500 Accuracy 0.3863
# Validation Loss: 3.4092 Validation Accuracy: 0.4753
# Time taken for 1 epoch: 71.35258197784424 secs
#
# Epoch 27 Batch 0 Loss 2.1852 Accuracy 0.3863
# Epoch 27 Batch 100 Loss 2.2679 Accuracy 0.3875
# Epoch 27 Batch 200 Loss 2.3167 Accuracy 0.3886
# Epoch 27 Batch 300 Loss 2.3706 Accuracy 0.3897
# Epoch 27 Batch 400 Loss 2.4076 Accuracy 0.3907
# Epoch 27 Batch 500 Loss 2.4394 Accuracy 0.3916
# Epoch 27 Batch 600 Loss 2.4729 Accuracy 0.3925
# Epoch 27 Loss 2.5011 Accuracy 0.3933
# Validation Loss: 3.3435 Validation Accuracy: 0.4841
# Time taken for 1 epoch: 75.23636651039124 secs
#
# Epoch 28 Batch 0 Loss 2.1692 Accuracy 0.3933
# Epoch 28 Batch 100 Loss 2.2371 Accuracy 0.3944
# Epoch 28 Batch 200 Loss 2.2875 Accuracy 0.3955
# Epoch 28 Batch 300 Loss 2.3196 Accuracy 0.3965
# Epoch 28 Batch 400 Loss 2.3550 Accuracy 0.3975
# Epoch 28 Batch 500 Loss 2.3899 Accuracy 0.3984
# Epoch 28 Batch 600 Loss 2.4245 Accuracy 0.3993
# Epoch 28 Loss 2.4453 Accuracy 0.4001
# Validation Loss: 3.2809 Validation Accuracy: 0.4925
# Time taken for 1 epoch: 71.30668139457703 secs
#
# Epoch 29 Batch 0 Loss 2.3040 Accuracy 0.4001
# Epoch 29 Batch 100 Loss 2.1861 Accuracy 0.4012
# Epoch 29 Batch 200 Loss 2.2239 Accuracy 0.4023
# Epoch 29 Batch 300 Loss 2.2669 Accuracy 0.4032
# Epoch 29 Batch 400 Loss 2.2958 Accuracy 0.4042
# Epoch 29 Batch 500 Loss 2.3364 Accuracy 0.4051
# Epoch 29 Batch 600 Loss 2.3641 Accuracy 0.4060
# Epoch 29 Loss 2.3868 Accuracy 0.4067
# Validation Loss: 3.2206 Validation Accuracy: 0.5006
# Time taken for 1 epoch: 71.32849979400635 secs
#
# Epoch 30 Batch 0 Loss 2.0748 Accuracy 0.4068
# Epoch 30 Batch 100 Loss 2.1518 Accuracy 0.4078
# Epoch 30 Batch 200 Loss 2.1783 Accuracy 0.4088
# Epoch 30 Batch 300 Loss 2.2232 Accuracy 0.4098
# Epoch 30 Batch 400 Loss 2.2609 Accuracy 0.4107
# Epoch 30 Batch 500 Loss 2.2937 Accuracy 0.4116
# Epoch 30 Batch 600 Loss 2.3258 Accuracy 0.4124
# Saving checkpoint for epoch 30 at checkpoints/ckpt-6
# Epoch 30 Loss 2.3536 Accuracy 0.4131
# Validation Loss: 3.1625 Validation Accuracy: 0.5085
# Time taken for 1 epoch: 72.10449409484863 secs
#
# Epoch 31 Batch 0 Loss 1.9792 Accuracy 0.4131
# Epoch 31 Batch 100 Loss 2.0796 Accuracy 0.4142
# Epoch 31 Batch 200 Loss 2.1191 Accuracy 0.4151
# Epoch 31 Batch 300 Loss 2.1654 Accuracy 0.4161
# Epoch 31 Batch 400 Loss 2.2053 Accuracy 0.4169
# Epoch 31 Batch 500 Loss 2.2407 Accuracy 0.4178
# Epoch 31 Batch 600 Loss 2.2751 Accuracy 0.4186
# Epoch 31 Loss 2.3018 Accuracy 0.4193
# Validation Loss: 3.1062 Validation Accuracy: 0.5163
# Time taken for 1 epoch: 71.22102165222168 secs
#
# Epoch 32 Batch 0 Loss 2.0816 Accuracy 0.4193
# Epoch 32 Batch 100 Loss 2.0804 Accuracy 0.4203
# Epoch 32 Batch 200 Loss 2.1124 Accuracy 0.4212
# Epoch 32 Batch 300 Loss 2.1470 Accuracy 0.4221
# Epoch 32 Batch 400 Loss 2.1695 Accuracy 0.4230
# Epoch 32 Batch 500 Loss 2.2052 Accuracy 0.4238
# Epoch 32 Batch 600 Loss 2.2324 Accuracy 0.4246
# Epoch 32 Loss 2.2642 Accuracy 0.4253
# Validation Loss: 3.0526 Validation Accuracy: 0.5238
# Time taken for 1 epoch: 71.22087597846985 secs
#
# Epoch 33 Batch 0 Loss 2.4246 Accuracy 0.4253
# Epoch 33 Batch 100 Loss 1.9982 Accuracy 0.4263
# Epoch 33 Batch 200 Loss 2.0532 Accuracy 0.4272
# Epoch 33 Batch 300 Loss 2.0876 Accuracy 0.4281
# Epoch 33 Batch 400 Loss 2.1187 Accuracy 0.4290
# Epoch 33 Batch 500 Loss 2.1577 Accuracy 0.4297
# Epoch 33 Batch 600 Loss 2.1979 Accuracy 0.4305
# Epoch 33 Loss 2.2240 Accuracy 0.4311
# Validation Loss: 3.0014 Validation Accuracy: 0.5310
# Time taken for 1 epoch: 71.22896409034729 secs
#
# Epoch 34 Batch 0 Loss 2.0241 Accuracy 0.4312
# Epoch 34 Batch 100 Loss 1.9985 Accuracy 0.4321
# Epoch 34 Batch 200 Loss 2.0277 Accuracy 0.4330
# Epoch 34 Batch 300 Loss 2.0691 Accuracy 0.4338
# Epoch 34 Batch 400 Loss 2.1054 Accuracy 0.4346
# Epoch 34 Batch 500 Loss 2.1362 Accuracy 0.4354
# Epoch 34 Batch 600 Loss 2.1648 Accuracy 0.4361
# Epoch 34 Loss 2.1911 Accuracy 0.4368
# Validation Loss: 2.9518 Validation Accuracy: 0.5380
# Time taken for 1 epoch: 71.22065877914429 secs
#
# Epoch 35 Batch 0 Loss 2.0372 Accuracy 0.4368
# Epoch 35 Batch 100 Loss 1.9474 Accuracy 0.4377
# Epoch 35 Batch 200 Loss 1.9930 Accuracy 0.4385
# Epoch 35 Batch 300 Loss 2.0265 Accuracy 0.4393
# Epoch 35 Batch 400 Loss 2.0556 Accuracy 0.4401
# Epoch 35 Batch 500 Loss 2.0894 Accuracy 0.4409
# Epoch 35 Batch 600 Loss 2.1274 Accuracy 0.4416
# Saving checkpoint for epoch 35 at checkpoints/ckpt-7
# Epoch 35 Loss 2.1569 Accuracy 0.4422
# Validation Loss: 2.9044 Validation Accuracy: 0.5447
# Time taken for 1 epoch: 71.98179149627686 secs
#
# Epoch 36 Batch 0 Loss 1.8584 Accuracy 0.4422
# Epoch 36 Batch 100 Loss 1.9025 Accuracy 0.4431
# Epoch 36 Batch 200 Loss 1.9401 Accuracy 0.4439
# Epoch 36 Batch 300 Loss 1.9739 Accuracy 0.4447
# Epoch 36 Batch 400 Loss 2.0144 Accuracy 0.4455
# Epoch 36 Batch 500 Loss 2.0538 Accuracy 0.4462
# Epoch 36 Batch 600 Loss 2.0866 Accuracy 0.4469
# Epoch 36 Loss 2.1141 Accuracy 0.4475
# Validation Loss: 2.8583 Validation Accuracy: 0.5513
# Time taken for 1 epoch: 71.6423168182373 secs
#
# Epoch 37 Batch 0 Loss 1.7425 Accuracy 0.4475
# Epoch 37 Batch 100 Loss 1.8702 Accuracy 0.4484
# Epoch 37 Batch 200 Loss 1.9039 Accuracy 0.4492
# Epoch 37 Batch 300 Loss 1.9471 Accuracy 0.4500
# Epoch 37 Batch 400 Loss 1.9847 Accuracy 0.4507
# Epoch 37 Batch 500 Loss 2.0205 Accuracy 0.4514
# Epoch 37 Batch 600 Loss 2.0551 Accuracy 0.4521
# Epoch 37 Loss 2.0860 Accuracy 0.4527
# Validation Loss: 2.8141 Validation Accuracy: 0.5576
# Time taken for 1 epoch: 71.51098847389221 secs
#
# Epoch 38 Batch 0 Loss 1.6411 Accuracy 0.4527
# Epoch 38 Batch 100 Loss 1.8408 Accuracy 0.4535
# Epoch 38 Batch 200 Loss 1.8921 Accuracy 0.4543
# Epoch 38 Batch 300 Loss 1.9271 Accuracy 0.4551
# Epoch 38 Batch 400 Loss 1.9663 Accuracy 0.4558
# Epoch 38 Batch 500 Loss 1.9929 Accuracy 0.4565
# Epoch 38 Batch 600 Loss 2.0233 Accuracy 0.4572
# Epoch 38 Loss 2.0510 Accuracy 0.4577
# Validation Loss: 2.7720 Validation Accuracy: 0.5636
# Time taken for 1 epoch: 71.22866797447205 secs
#
# Epoch 39 Batch 0 Loss 1.6224 Accuracy 0.4577
# Epoch 39 Batch 100 Loss 1.7976 Accuracy 0.4585
# Epoch 39 Batch 200 Loss 1.8503 Accuracy 0.4593
# Epoch 39 Batch 300 Loss 1.8920 Accuracy 0.4600
# Epoch 39 Batch 400 Loss 1.9326 Accuracy 0.4607
# Epoch 39 Batch 500 Loss 1.9639 Accuracy 0.4614
# Epoch 39 Batch 600 Loss 2.0003 Accuracy 0.4620
# Epoch 39 Loss 2.0240 Accuracy 0.4626
# Validation Loss: 2.7302 Validation Accuracy: 0.5696
# Time taken for 1 epoch: 71.22249388694763 secs
#
# Epoch 40 Batch 0 Loss 1.8556 Accuracy 0.4626
# Epoch 40 Batch 100 Loss 1.7676 Accuracy 0.4634
# Epoch 40 Batch 200 Loss 1.8101 Accuracy 0.4641
# Epoch 40 Batch 300 Loss 1.8437 Accuracy 0.4648
# Epoch 40 Batch 400 Loss 1.8883 Accuracy 0.4655
# Epoch 40 Batch 500 Loss 1.9236 Accuracy 0.4662
# Epoch 40 Batch 600 Loss 1.9599 Accuracy 0.4668
# Saving checkpoint for epoch 40 at checkpoints/ckpt-8
# Epoch 40 Loss 1.9885 Accuracy 0.4673
# Validation Loss: 2.6901 Validation Accuracy: 0.5754
# Time taken for 1 epoch: 72.00503611564636 secs
#
# Epoch 41 Batch 0 Loss 1.5322 Accuracy 0.4673
# Epoch 41 Batch 100 Loss 1.7594 Accuracy 0.4681
# Epoch 41 Batch 200 Loss 1.7993 Accuracy 0.4688
# Epoch 41 Batch 300 Loss 1.8338 Accuracy 0.4695
# Epoch 41 Batch 400 Loss 1.8661 Accuracy 0.4702
# Epoch 41 Batch 500 Loss 1.9027 Accuracy 0.4708
# Epoch 41 Batch 600 Loss 1.9386 Accuracy 0.4714
# Epoch 41 Loss 1.9646 Accuracy 0.4719
# Validation Loss: 2.6517 Validation Accuracy: 0.5810
# Time taken for 1 epoch: 71.2544617652893 secs
#
# Epoch 42 Batch 0 Loss 1.7813 Accuracy 0.4719
# Epoch 42 Batch 100 Loss 1.7035 Accuracy 0.4727
# Epoch 42 Batch 200 Loss 1.7458 Accuracy 0.4734
# Epoch 42 Batch 300 Loss 1.7951 Accuracy 0.4741
# Epoch 42 Batch 400 Loss 1.8383 Accuracy 0.4747
# Epoch 42 Batch 500 Loss 1.8750 Accuracy 0.4754
# Epoch 42 Batch 600 Loss 1.9106 Accuracy 0.4760
# Epoch 42 Loss 1.9379 Accuracy 0.4765
# Validation Loss: 2.6147 Validation Accuracy: 0.5864
# Time taken for 1 epoch: 71.5011785030365 secs
#
# Epoch 43 Batch 0 Loss 1.6301 Accuracy 0.4765
# Epoch 43 Batch 100 Loss 1.6982 Accuracy 0.4772
# Epoch 43 Batch 200 Loss 1.7377 Accuracy 0.4779
# Epoch 43 Batch 300 Loss 1.7734 Accuracy 0.4786
# Epoch 43 Batch 400 Loss 1.8101 Accuracy 0.4792
# Epoch 43 Batch 500 Loss 1.8496 Accuracy 0.4798
# Epoch 43 Batch 600 Loss 1.8832 Accuracy 0.4804
# Epoch 43 Loss 1.9105 Accuracy 0.4809
# Validation Loss: 2.5792 Validation Accuracy: 0.5916
# Time taken for 1 epoch: 71.19656300544739 secs
#
# Epoch 44 Batch 0 Loss 1.6545 Accuracy 0.4809
# Epoch 44 Batch 100 Loss 1.7000 Accuracy 0.4816
# Epoch 44 Batch 200 Loss 1.7299 Accuracy 0.4822
# Epoch 44 Batch 300 Loss 1.7621 Accuracy 0.4829
# Epoch 44 Batch 400 Loss 1.7982 Accuracy 0.4835
# Epoch 44 Batch 500 Loss 1.8327 Accuracy 0.4841
# Epoch 44 Batch 600 Loss 1.8622 Accuracy 0.4847
# Epoch 44 Loss 1.8913 Accuracy 0.4851
# Validation Loss: 2.5446 Validation Accuracy: 0.5967
# Time taken for 1 epoch: 71.20506644248962 secs
#
# Epoch 45 Batch 0 Loss 1.3522 Accuracy 0.4852
# Epoch 45 Batch 100 Loss 1.6545 Accuracy 0.4859
# Epoch 45 Batch 200 Loss 1.6996 Accuracy 0.4865
# Epoch 45 Batch 300 Loss 1.7384 Accuracy 0.4871
# Epoch 45 Batch 400 Loss 1.7767 Accuracy 0.4877
# Epoch 45 Batch 500 Loss 1.8062 Accuracy 0.4883
# Epoch 45 Batch 600 Loss 1.8382 Accuracy 0.4889
# Saving checkpoint for epoch 45 at checkpoints/ckpt-9
# Epoch 45 Loss 1.8662 Accuracy 0.4893
# Validation Loss: 2.5107 Validation Accuracy: 0.6017
# Time taken for 1 epoch: 71.98717379570007 secs
#
# Epoch 46 Batch 0 Loss 1.4064 Accuracy 0.4893
# Epoch 46 Batch 100 Loss 1.6118 Accuracy 0.4900
# Epoch 46 Batch 200 Loss 1.6607 Accuracy 0.4907
# Epoch 46 Batch 300 Loss 1.7087 Accuracy 0.4913
# Epoch 46 Batch 400 Loss 1.7485 Accuracy 0.4919
# Epoch 46 Batch 500 Loss 1.7842 Accuracy 0.4924
# Epoch 46 Batch 600 Loss 1.8159 Accuracy 0.4930
# Epoch 46 Loss 1.8460 Accuracy 0.4934
# Validation Loss: 2.4781 Validation Accuracy: 0.6064
# Time taken for 1 epoch: 71.19281458854675 secs
#
# Epoch 47 Batch 0 Loss 1.6159 Accuracy 0.4934
# Epoch 47 Batch 100 Loss 1.6070 Accuracy 0.4941
# Epoch 47 Batch 200 Loss 1.6499 Accuracy 0.4947
# Epoch 47 Batch 300 Loss 1.6804 Accuracy 0.4953
# Epoch 47 Batch 400 Loss 1.7252 Accuracy 0.4959
# Epoch 47 Batch 500 Loss 1.7605 Accuracy 0.4964
# Epoch 47 Batch 600 Loss 1.7943 Accuracy 0.4970
# Epoch 47 Loss 1.8227 Accuracy 0.4974
# Validation Loss: 2.4462 Validation Accuracy: 0.6112
# Time taken for 1 epoch: 71.59603810310364 secs
#
# Epoch 48 Batch 0 Loss 1.2241 Accuracy 0.4974
# Epoch 48 Batch 100 Loss 1.5777 Accuracy 0.4981
# Epoch 48 Batch 200 Loss 1.6298 Accuracy 0.4987
# Epoch 48 Batch 300 Loss 1.6669 Accuracy 0.4993
# Epoch 48 Batch 400 Loss 1.7076 Accuracy 0.4998
# Epoch 48 Batch 500 Loss 1.7395 Accuracy 0.5003
# Epoch 48 Batch 600 Loss 1.7736 Accuracy 0.5009
# Epoch 48 Loss 1.7987 Accuracy 0.5013
# Validation Loss: 2.4153 Validation Accuracy: 0.6157
# Time taken for 1 epoch: 71.37097644805908 secs
#
# Epoch 49 Batch 0 Loss 1.9041 Accuracy 0.5013
# Epoch 49 Batch 100 Loss 1.5737 Accuracy 0.5020
# Epoch 49 Batch 200 Loss 1.6061 Accuracy 0.5026
# Epoch 49 Batch 300 Loss 1.6459 Accuracy 0.5031
# Epoch 49 Batch 400 Loss 1.6786 Accuracy 0.5037
# Epoch 49 Batch 500 Loss 1.7186 Accuracy 0.5042
# Epoch 49 Batch 600 Loss 1.7513 Accuracy 0.5047
# Epoch 49 Loss 1.7817 Accuracy 0.5051
# Validation Loss: 2.3848 Validation Accuracy: 0.6203
# Time taken for 1 epoch: 71.31464052200317 secs
#
# Epoch 50 Batch 0 Loss 1.5509 Accuracy 0.5051
# Epoch 50 Batch 100 Loss 1.5221 Accuracy 0.5058
# Epoch 50 Batch 200 Loss 1.5756 Accuracy 0.5063
# Epoch 50 Batch 300 Loss 1.6167 Accuracy 0.5069
# Epoch 50 Batch 400 Loss 1.6522 Accuracy 0.5074
# Epoch 50 Batch 500 Loss 1.6867 Accuracy 0.5080
# Epoch 50 Batch 600 Loss 1.7274 Accuracy 0.5084
# Saving checkpoint for epoch 50 at checkpoints/ckpt-10
# Epoch 50 Loss 1.7552 Accuracy 0.5088
# Validation Loss: 2.3554 Validation Accuracy: 0.6247
# Time taken for 1 epoch: 72.33669400215149 secs
#
# Epoch 51 Batch 0 Loss 1.4060 Accuracy 0.5089
# Epoch 51 Batch 100 Loss 1.5406 Accuracy 0.5095
# Epoch 51 Batch 200 Loss 1.5797 Accuracy 0.5100
# Epoch 51 Batch 300 Loss 1.6182 Accuracy 0.5106
# Epoch 51 Batch 400 Loss 1.6458 Accuracy 0.5111
# Epoch 51 Batch 500 Loss 1.6799 Accuracy 0.5116
# Epoch 51 Batch 600 Loss 1.7150 Accuracy 0.5121
# Epoch 51 Loss 1.7439 Accuracy 0.5125
# Validation Loss: 2.3268 Validation Accuracy: 0.6290
# Time taken for 1 epoch: 71.22932457923889 secs
#
# Epoch 52 Batch 0 Loss 1.5462 Accuracy 0.5125
# Epoch 52 Batch 100 Loss 1.5102 Accuracy 0.5131
# Epoch 52 Batch 200 Loss 1.5568 Accuracy 0.5136
# Epoch 52 Batch 300 Loss 1.5999 Accuracy 0.5141
# Epoch 52 Batch 400 Loss 1.6357 Accuracy 0.5147
# Epoch 52 Batch 500 Loss 1.6643 Accuracy 0.5151
# Epoch 52 Batch 600 Loss 1.6965 Accuracy 0.5156
# Epoch 52 Loss 1.7200 Accuracy 0.5160
# Validation Loss: 2.2990 Validation Accuracy: 0.6331
# Time taken for 1 epoch: 71.22419905662537 secs
#
# Epoch 53 Batch 0 Loss 1.4145 Accuracy 0.5160
# Epoch 53 Batch 100 Loss 1.4737 Accuracy 0.5166
# Epoch 53 Batch 200 Loss 1.5359 Accuracy 0.5172
# Epoch 53 Batch 300 Loss 1.5770 Accuracy 0.5177
# Epoch 53 Batch 400 Loss 1.6104 Accuracy 0.5182
# Epoch 53 Batch 500 Loss 1.6396 Accuracy 0.5187
# Epoch 53 Batch 600 Loss 1.6765 Accuracy 0.5191
# Epoch 53 Loss 1.7026 Accuracy 0.5195
# Validation Loss: 2.2720 Validation Accuracy: 0.6371
# Time taken for 1 epoch: 71.1839337348938 secs
#
# Epoch 54 Batch 0 Loss 1.5826 Accuracy 0.5195
# Epoch 54 Batch 100 Loss 1.4577 Accuracy 0.5201
# Epoch 54 Batch 200 Loss 1.5014 Accuracy 0.5206
# Epoch 54 Batch 300 Loss 1.5454 Accuracy 0.5211
# Epoch 54 Batch 400 Loss 1.5886 Accuracy 0.5216
# Epoch 54 Batch 500 Loss 1.6287 Accuracy 0.5221
# Epoch 54 Batch 600 Loss 1.6566 Accuracy 0.5225
# Epoch 54 Loss 1.6823 Accuracy 0.5229
# Validation Loss: 2.2458 Validation Accuracy: 0.6411
# Time taken for 1 epoch: 71.32143473625183 secs
#
# Epoch 55 Batch 0 Loss 1.1563 Accuracy 0.5229
# Epoch 55 Batch 100 Loss 1.4498 Accuracy 0.5235
# Epoch 55 Batch 200 Loss 1.4889 Accuracy 0.5240
# Epoch 55 Batch 300 Loss 1.5303 Accuracy 0.5245
# Epoch 55 Batch 400 Loss 1.5752 Accuracy 0.5250
# Epoch 55 Batch 500 Loss 1.6101 Accuracy 0.5254
# Epoch 55 Batch 600 Loss 1.6427 Accuracy 0.5259
# Saving checkpoint for epoch 55 at checkpoints/ckpt-11
# Epoch 55 Loss 1.6699 Accuracy 0.5262
# Validation Loss: 2.2200 Validation Accuracy: 0.6450
# Time taken for 1 epoch: 71.96278738975525 secs
#
# Epoch 56 Batch 0 Loss 1.3023 Accuracy 0.5263
# Epoch 56 Batch 100 Loss 1.4439 Accuracy 0.5268
# Epoch 56 Batch 200 Loss 1.4892 Accuracy 0.5273
# Epoch 56 Batch 300 Loss 1.5184 Accuracy 0.5278
# Epoch 56 Batch 400 Loss 1.5574 Accuracy 0.5283
# Epoch 56 Batch 500 Loss 1.5915 Accuracy 0.5287
# Epoch 56 Batch 600 Loss 1.6242 Accuracy 0.5291
# Epoch 56 Loss 1.6511 Accuracy 0.5295
# Validation Loss: 2.1955 Validation Accuracy: 0.6488
# Time taken for 1 epoch: 71.34732151031494 secs
#
# Epoch 57 Batch 0 Loss 1.3736 Accuracy 0.5295
# Epoch 57 Batch 100 Loss 1.4316 Accuracy 0.5301
# Epoch 57 Batch 200 Loss 1.4626 Accuracy 0.5306
# Epoch 57 Batch 300 Loss 1.5095 Accuracy 0.5310
# Epoch 57 Batch 400 Loss 1.5456 Accuracy 0.5315
# Epoch 57 Batch 500 Loss 1.5801 Accuracy 0.5319
# Epoch 57 Batch 600 Loss 1.6173 Accuracy 0.5324
# Epoch 57 Loss 1.6397 Accuracy 0.5327
# Validation Loss: 2.1712 Validation Accuracy: 0.6525
# Time taken for 1 epoch: 71.50374913215637 secs
#
# Epoch 58 Batch 0 Loss 1.4887 Accuracy 0.5327
# Epoch 58 Batch 100 Loss 1.4081 Accuracy 0.5333
# Epoch 58 Batch 200 Loss 1.4446 Accuracy 0.5337
# Epoch 58 Batch 300 Loss 1.4772 Accuracy 0.5342
# Epoch 58 Batch 400 Loss 1.5215 Accuracy 0.5347
# Epoch 58 Batch 500 Loss 1.5559 Accuracy 0.5351
# Epoch 58 Batch 600 Loss 1.5917 Accuracy 0.5355
# Epoch 58 Loss 1.6190 Accuracy 0.5359
# Validation Loss: 2.1478 Validation Accuracy: 0.6560
# Time taken for 1 epoch: 71.36702466011047 secs
#
# Epoch 59 Batch 0 Loss 1.2333 Accuracy 0.5359
# Epoch 59 Batch 100 Loss 1.4189 Accuracy 0.5364
# Epoch 59 Batch 200 Loss 1.4466 Accuracy 0.5369
# Epoch 59 Batch 300 Loss 1.4885 Accuracy 0.5373
# Epoch 59 Batch 400 Loss 1.5245 Accuracy 0.5377
# Epoch 59 Batch 500 Loss 1.5563 Accuracy 0.5382
# Epoch 59 Batch 600 Loss 1.5897 Accuracy 0.5386
# Epoch 59 Loss 1.6138 Accuracy 0.5389
# Validation Loss: 2.1252 Validation Accuracy: 0.6595
# Time taken for 1 epoch: 71.33679866790771 secs
#
# Epoch 60 Batch 0 Loss 1.7529 Accuracy 0.5389
# Epoch 60 Batch 100 Loss 1.3918 Accuracy 0.5394
# Epoch 60 Batch 200 Loss 1.4148 Accuracy 0.5399
# Epoch 60 Batch 300 Loss 1.4596 Accuracy 0.5404
# Epoch 60 Batch 400 Loss 1.4920 Accuracy 0.5408
# Epoch 60 Batch 500 Loss 1.5299 Accuracy 0.5412
# Epoch 60 Batch 600 Loss 1.5614 Accuracy 0.5416
# Saving checkpoint for epoch 60 at checkpoints/ckpt-12
# Epoch 60 Loss 1.5863 Accuracy 0.5419
# Validation Loss: 2.1026 Validation Accuracy: 0.6630
# Time taken for 1 epoch: 72.40829491615295 secs
#
# Epoch 61 Batch 0 Loss 1.2170 Accuracy 0.5419
# Epoch 61 Batch 100 Loss 1.3305 Accuracy 0.5425
# Epoch 61 Batch 200 Loss 1.3845 Accuracy 0.5429
# Epoch 61 Batch 300 Loss 1.4402 Accuracy 0.5434
# Epoch 61 Batch 400 Loss 1.4740 Accuracy 0.5438
# Epoch 61 Batch 500 Loss 1.5088 Accuracy 0.5442
# Epoch 61 Batch 600 Loss 1.5431 Accuracy 0.5446
# Epoch 61 Loss 1.5744 Accuracy 0.5449
# Validation Loss: 2.0803 Validation Accuracy: 0.6664
# Time taken for 1 epoch: 71.35091042518616 secs
#
# Epoch 62 Batch 0 Loss 1.4671 Accuracy 0.5449
# Epoch 62 Batch 100 Loss 1.3543 Accuracy 0.5454
# Epoch 62 Batch 200 Loss 1.3787 Accuracy 0.5459
# Epoch 62 Batch 300 Loss 1.4188 Accuracy 0.5463
# Epoch 62 Batch 400 Loss 1.4565 Accuracy 0.5467
# Epoch 62 Batch 500 Loss 1.4921 Accuracy 0.5471
# Epoch 62 Batch 600 Loss 1.5287 Accuracy 0.5475
# Epoch 62 Loss 1.5607 Accuracy 0.5478
# Validation Loss: 2.0590 Validation Accuracy: 0.6697
# Time taken for 1 epoch: 71.23919677734375 secs
#
# Epoch 63 Batch 0 Loss 1.3099 Accuracy 0.5478
# Epoch 63 Batch 100 Loss 1.3351 Accuracy 0.5483
# Epoch 63 Batch 200 Loss 1.3771 Accuracy 0.5487
# Epoch 63 Batch 300 Loss 1.4171 Accuracy 0.5492
# Epoch 63 Batch 400 Loss 1.4542 Accuracy 0.5496
# Epoch 63 Batch 500 Loss 1.4850 Accuracy 0.5500
# Epoch 63 Batch 600 Loss 1.5185 Accuracy 0.5503
# Epoch 63 Loss 1.5475 Accuracy 0.5507
# Validation Loss: 2.0383 Validation Accuracy: 0.6729
# Time taken for 1 epoch: 71.21703505516052 secs
#
# Epoch 64 Batch 0 Loss 1.2357 Accuracy 0.5507
# Epoch 64 Batch 100 Loss 1.3569 Accuracy 0.5511
# Epoch 64 Batch 200 Loss 1.3722 Accuracy 0.5516
# Epoch 64 Batch 300 Loss 1.4129 Accuracy 0.5520
# Epoch 64 Batch 400 Loss 1.4523 Accuracy 0.5524
# Epoch 64 Batch 500 Loss 1.4829 Accuracy 0.5527
# Epoch 64 Batch 600 Loss 1.5133 Accuracy 0.5531
# Epoch 64 Loss 1.5377 Accuracy 0.5534
# Validation Loss: 2.0177 Validation Accuracy: 0.6761
# Time taken for 1 epoch: 71.50587368011475 secs
#
# Epoch 65 Batch 0 Loss 1.2957 Accuracy 0.5534
# Epoch 65 Batch 100 Loss 1.3137 Accuracy 0.5539
# Epoch 65 Batch 200 Loss 1.3585 Accuracy 0.5543
# Epoch 65 Batch 300 Loss 1.3939 Accuracy 0.5547
# Epoch 65 Batch 400 Loss 1.4291 Accuracy 0.5551
# Epoch 65 Batch 500 Loss 1.4576 Accuracy 0.5555
# Epoch 65 Batch 600 Loss 1.4915 Accuracy 0.5559
# Saving checkpoint for epoch 65 at checkpoints/ckpt-13
# Epoch 65 Loss 1.5241 Accuracy 0.5562
# Validation Loss: 1.9980 Validation Accuracy: 0.6791
# Time taken for 1 epoch: 72.14666867256165 secs
#
# Epoch 66 Batch 0 Loss 1.2910 Accuracy 0.5562
# Epoch 66 Batch 100 Loss 1.3088 Accuracy 0.5566
# Epoch 66 Batch 200 Loss 1.3402 Accuracy 0.5571
# Epoch 66 Batch 300 Loss 1.3761 Accuracy 0.5575
# Epoch 66 Batch 400 Loss 1.4127 Accuracy 0.5578
# Epoch 66 Batch 500 Loss 1.4436 Accuracy 0.5582
# Epoch 66 Batch 600 Loss 1.4777 Accuracy 0.5586
# Epoch 66 Loss 1.5079 Accuracy 0.5589
# Validation Loss: 1.9781 Validation Accuracy: 0.6822
# Time taken for 1 epoch: 71.33867025375366 secs
#
# Epoch 67 Batch 0 Loss 1.4059 Accuracy 0.5589
# Epoch 67 Batch 100 Loss 1.3008 Accuracy 0.5593
# Epoch 67 Batch 200 Loss 1.3399 Accuracy 0.5597
# Epoch 67 Batch 300 Loss 1.3751 Accuracy 0.5601
# Epoch 67 Batch 400 Loss 1.4081 Accuracy 0.5605
# Epoch 67 Batch 500 Loss 1.4386 Accuracy 0.5609
# Epoch 67 Batch 600 Loss 1.4731 Accuracy 0.5612
# Epoch 67 Loss 1.4956 Accuracy 0.5615
# Validation Loss: 1.9592 Validation Accuracy: 0.6851
# Time taken for 1 epoch: 71.21125268936157 secs
#
# Epoch 68 Batch 0 Loss 1.3308 Accuracy 0.5615
# Epoch 68 Batch 100 Loss 1.2928 Accuracy 0.5619
# Epoch 68 Batch 200 Loss 1.3217 Accuracy 0.5624
# Epoch 68 Batch 300 Loss 1.3554 Accuracy 0.5627
# Epoch 68 Batch 400 Loss 1.3886 Accuracy 0.5631
# Epoch 68 Batch 500 Loss 1.4233 Accuracy 0.5635
# Epoch 68 Batch 600 Loss 1.4585 Accuracy 0.5638
# Epoch 68 Loss 1.4865 Accuracy 0.5641
# Validation Loss: 1.9410 Validation Accuracy: 0.6879
# Time taken for 1 epoch: 71.17475366592407 secs
#
# Epoch 69 Batch 0 Loss 1.4387 Accuracy 0.5641
# Epoch 69 Batch 100 Loss 1.2576 Accuracy 0.5645
# Epoch 69 Batch 200 Loss 1.2959 Accuracy 0.5649
# Epoch 69 Batch 300 Loss 1.3277 Accuracy 0.5653
# Epoch 69 Batch 400 Loss 1.3666 Accuracy 0.5657
# Epoch 69 Batch 500 Loss 1.4024 Accuracy 0.5661
# Epoch 69 Batch 600 Loss 1.4380 Accuracy 0.5664
# Epoch 69 Loss 1.4685 Accuracy 0.5667
# Validation Loss: 1.9228 Validation Accuracy: 0.6908
# Time taken for 1 epoch: 71.31289434432983 secs
#
# Epoch 70 Batch 0 Loss 1.3885 Accuracy 0.5667
# Epoch 70 Batch 100 Loss 1.2916 Accuracy 0.5671
# Epoch 70 Batch 200 Loss 1.3109 Accuracy 0.5675
# Epoch 70 Batch 300 Loss 1.3477 Accuracy 0.5678
# Epoch 70 Batch 400 Loss 1.3767 Accuracy 0.5682
# Epoch 70 Batch 500 Loss 1.4070 Accuracy 0.5685
# Epoch 70 Batch 600 Loss 1.4362 Accuracy 0.5689
# Saving checkpoint for epoch 70 at checkpoints/ckpt-14
# Epoch 70 Loss 1.4643 Accuracy 0.5692
# Validation Loss: 1.9046 Validation Accuracy: 0.6936
# Time taken for 1 epoch: 72.12369346618652 secs
#
# Epoch 71 Batch 0 Loss 1.3721 Accuracy 0.5692
# Epoch 71 Batch 100 Loss 1.2518 Accuracy 0.5696
# Epoch 71 Batch 200 Loss 1.2869 Accuracy 0.5700
# Epoch 71 Batch 300 Loss 1.3264 Accuracy 0.5703
# Epoch 71 Batch 400 Loss 1.3644 Accuracy 0.5707
# Epoch 71 Batch 500 Loss 1.3959 Accuracy 0.5710
# Epoch 71 Batch 600 Loss 1.4249 Accuracy 0.5714
# Epoch 71 Loss 1.4498 Accuracy 0.5716
# Validation Loss: 1.8872 Validation Accuracy: 0.6963
# Time taken for 1 epoch: 71.23240804672241 secs
#
# Epoch 72 Batch 0 Loss 1.2421 Accuracy 0.5716
# Epoch 72 Batch 100 Loss 1.2385 Accuracy 0.5720
# Epoch 72 Batch 200 Loss 1.2745 Accuracy 0.5724
# Epoch 72 Batch 300 Loss 1.3062 Accuracy 0.5728
# Epoch 72 Batch 400 Loss 1.3433 Accuracy 0.5731
# Epoch 72 Batch 500 Loss 1.3769 Accuracy 0.5735
# Epoch 72 Batch 600 Loss 1.4113 Accuracy 0.5738
# Epoch 72 Loss 1.4385 Accuracy 0.5741
# Validation Loss: 1.8705 Validation Accuracy: 0.6990
# Time taken for 1 epoch: 71.23089933395386 secs
#
# Epoch 73 Batch 0 Loss 1.3000 Accuracy 0.5741
# Epoch 73 Batch 100 Loss 1.2185 Accuracy 0.5745
# Epoch 73 Batch 200 Loss 1.2539 Accuracy 0.5749
# Epoch 73 Batch 300 Loss 1.2858 Accuracy 0.5752
# Epoch 73 Batch 400 Loss 1.3184 Accuracy 0.5756
# Epoch 73 Batch 500 Loss 1.3571 Accuracy 0.5759
# Epoch 73 Batch 600 Loss 1.3925 Accuracy 0.5762
# Epoch 73 Loss 1.4237 Accuracy 0.5765
# Validation Loss: 1.8538 Validation Accuracy: 0.7016
# Time taken for 1 epoch: 71.23117756843567 secs
#
# Epoch 74 Batch 0 Loss 1.1741 Accuracy 0.5765
# Epoch 74 Batch 100 Loss 1.2028 Accuracy 0.5769
# Epoch 74 Batch 200 Loss 1.2617 Accuracy 0.5772
# Epoch 74 Batch 300 Loss 1.2984 Accuracy 0.5776
# Epoch 74 Batch 400 Loss 1.3381 Accuracy 0.5779
# Epoch 74 Batch 500 Loss 1.3684 Accuracy 0.5782
# Epoch 74 Batch 600 Loss 1.3993 Accuracy 0.5785
# Epoch 74 Loss 1.4274 Accuracy 0.5788
# Validation Loss: 1.8374 Validation Accuracy: 0.7042
# Time taken for 1 epoch: 71.20939135551453 secs
#
# Epoch 75 Batch 0 Loss 1.0737 Accuracy 0.5788
# Epoch 75 Batch 100 Loss 1.2069 Accuracy 0.5792
# Epoch 75 Batch 200 Loss 1.2372 Accuracy 0.5796
# Epoch 75 Batch 300 Loss 1.2759 Accuracy 0.5799
# Epoch 75 Batch 400 Loss 1.3080 Accuracy 0.5802
# Epoch 75 Batch 500 Loss 1.3422 Accuracy 0.5806
# Epoch 75 Batch 600 Loss 1.3801 Accuracy 0.5809
# Saving checkpoint for epoch 75 at checkpoints/ckpt-15
# Epoch 75 Loss 1.4074 Accuracy 0.5811
# Validation Loss: 1.8214 Validation Accuracy: 0.7067
# Time taken for 1 epoch: 71.97781705856323 secs
#
# Epoch 76 Batch 0 Loss 1.2327 Accuracy 0.5811
# Epoch 76 Batch 100 Loss 1.1909 Accuracy 0.5815
# Epoch 76 Batch 200 Loss 1.2472 Accuracy 0.5818
# Epoch 76 Batch 300 Loss 1.2796 Accuracy 0.5822
# Epoch 76 Batch 400 Loss 1.3048 Accuracy 0.5825
# Epoch 76 Batch 500 Loss 1.3377 Accuracy 0.5828
# Epoch 76 Batch 600 Loss 1.3719 Accuracy 0.5831
# Epoch 76 Loss 1.3957 Accuracy 0.5834
# Validation Loss: 1.8056 Validation Accuracy: 0.7091
# Time taken for 1 epoch: 71.3385636806488 secs
#
# Epoch 77 Batch 0 Loss 1.2304 Accuracy 0.5834
# Epoch 77 Batch 100 Loss 1.1673 Accuracy 0.5838
# Epoch 77 Batch 200 Loss 1.2137 Accuracy 0.5841
# Epoch 77 Batch 300 Loss 1.2567 Accuracy 0.5844
# Epoch 77 Batch 400 Loss 1.2953 Accuracy 0.5847
# Epoch 77 Batch 500 Loss 1.3257 Accuracy 0.5851
# Epoch 77 Batch 600 Loss 1.3631 Accuracy 0.5854
# Epoch 77 Loss 1.3910 Accuracy 0.5856
# Validation Loss: 1.7902 Validation Accuracy: 0.7115
# Time taken for 1 epoch: 71.33050322532654 secs
#
# Epoch 78 Batch 0 Loss 1.1914 Accuracy 0.5856
# Epoch 78 Batch 100 Loss 1.1872 Accuracy 0.5860
# Epoch 78 Batch 200 Loss 1.2247 Accuracy 0.5863
# Epoch 78 Batch 300 Loss 1.2546 Accuracy 0.5867
# Epoch 78 Batch 400 Loss 1.2923 Accuracy 0.5870
# Epoch 78 Batch 500 Loss 1.3250 Accuracy 0.5873
# Epoch 78 Batch 600 Loss 1.3552 Accuracy 0.5876
# Epoch 78 Loss 1.3833 Accuracy 0.5878
# Validation Loss: 1.7753 Validation Accuracy: 0.7139
# Time taken for 1 epoch: 71.22781419754028 secs
#
# Epoch 79 Batch 0 Loss 0.9108 Accuracy 0.5878
# Epoch 79 Batch 100 Loss 1.1723 Accuracy 0.5882
# Epoch 79 Batch 200 Loss 1.2154 Accuracy 0.5885
# Epoch 79 Batch 300 Loss 1.2489 Accuracy 0.5888
# Epoch 79 Batch 400 Loss 1.2785 Accuracy 0.5891
# Epoch 79 Batch 500 Loss 1.3119 Accuracy 0.5894
# Epoch 79 Batch 600 Loss 1.3467 Accuracy 0.5897
# Epoch 79 Loss 1.3732 Accuracy 0.5900
# Validation Loss: 1.7606 Validation Accuracy: 0.7162
# Time taken for 1 epoch: 71.1738429069519 secs
#
# Epoch 80 Batch 0 Loss 1.3691 Accuracy 0.5900
# Epoch 80 Batch 100 Loss 1.1695 Accuracy 0.5903
# Epoch 80 Batch 200 Loss 1.2059 Accuracy 0.5907
# Epoch 80 Batch 300 Loss 1.2408 Accuracy 0.5910
# Epoch 80 Batch 400 Loss 1.2727 Accuracy 0.5913
# Epoch 80 Batch 500 Loss 1.3061 Accuracy 0.5916
# Epoch 80 Batch 600 Loss 1.3349 Accuracy 0.5919
# Saving checkpoint for epoch 80 at checkpoints/ckpt-16
# Epoch 80 Loss 1.3641 Accuracy 0.5921
# Validation Loss: 1.7462 Validation Accuracy: 0.7185
# Time taken for 1 epoch: 72.31653571128845 secs
#
# Epoch 81 Batch 0 Loss 1.0674 Accuracy 0.5921
# Epoch 81 Batch 100 Loss 1.1613 Accuracy 0.5924
# Epoch 81 Batch 200 Loss 1.2009 Accuracy 0.5928
# Epoch 81 Batch 300 Loss 1.2366 Accuracy 0.5931
# Epoch 81 Batch 400 Loss 1.2652 Accuracy 0.5934
# Epoch 81 Batch 500 Loss 1.2938 Accuracy 0.5937
# Epoch 81 Batch 600 Loss 1.3245 Accuracy 0.5939
# Epoch 81 Loss 1.3520 Accuracy 0.5942
# Validation Loss: 1.7320 Validation Accuracy: 0.7207
# Time taken for 1 epoch: 71.3419897556305 secs
#
# Epoch 82 Batch 0 Loss 1.1615 Accuracy 0.5942
# Epoch 82 Batch 100 Loss 1.1608 Accuracy 0.5945
# Epoch 82 Batch 200 Loss 1.1959 Accuracy 0.5949
# Epoch 82 Batch 300 Loss 1.2277 Accuracy 0.5952
# Epoch 82 Batch 400 Loss 1.2573 Accuracy 0.5955
# Epoch 82 Batch 500 Loss 1.2880 Accuracy 0.5957
# Epoch 82 Batch 600 Loss 1.3189 Accuracy 0.5960
# Epoch 82 Loss 1.3488 Accuracy 0.5962
# Validation Loss: 1.7181 Validation Accuracy: 0.7229
# Time taken for 1 epoch: 71.25803732872009 secs
#
# Epoch 83 Batch 0 Loss 1.0837 Accuracy 0.5962
# Epoch 83 Batch 100 Loss 1.1341 Accuracy 0.5966
# Epoch 83 Batch 200 Loss 1.1651 Accuracy 0.5969
# Epoch 83 Batch 300 Loss 1.2110 Accuracy 0.5972
# Epoch 83 Batch 400 Loss 1.2442 Accuracy 0.5975
# Epoch 83 Batch 500 Loss 1.2739 Accuracy 0.5978
# Epoch 83 Batch 600 Loss 1.3097 Accuracy 0.5980
# Epoch 83 Loss 1.3354 Accuracy 0.5983
# Validation Loss: 1.7047 Validation Accuracy: 0.7250
# Time taken for 1 epoch: 71.2284607887268 secs
#
# Epoch 84 Batch 0 Loss 1.3262 Accuracy 0.5983
# Epoch 84 Batch 100 Loss 1.1457 Accuracy 0.5986
# Epoch 84 Batch 200 Loss 1.1630 Accuracy 0.5989
# Epoch 84 Batch 300 Loss 1.2105 Accuracy 0.5992
# Epoch 84 Batch 400 Loss 1.2435 Accuracy 0.5995
# Epoch 84 Batch 500 Loss 1.2734 Accuracy 0.5998
# Epoch 84 Batch 600 Loss 1.3036 Accuracy 0.6000
# Epoch 84 Loss 1.3315 Accuracy 0.6003
# Validation Loss: 1.6915 Validation Accuracy: 0.7271
# Time taken for 1 epoch: 71.5143792629242 secs
#
# Epoch 85 Batch 0 Loss 1.2201 Accuracy 0.6003
# Epoch 85 Batch 100 Loss 1.1138 Accuracy 0.6006
# Epoch 85 Batch 200 Loss 1.1643 Accuracy 0.6009
# Epoch 85 Batch 300 Loss 1.1886 Accuracy 0.6012
# Epoch 85 Batch 400 Loss 1.2242 Accuracy 0.6015
# Epoch 85 Batch 500 Loss 1.2556 Accuracy 0.6018
# Epoch 85 Batch 600 Loss 1.2881 Accuracy 0.6020
# Saving checkpoint for epoch 85 at checkpoints/ckpt-17
# Epoch 85 Loss 1.3150 Accuracy 0.6022
# Validation Loss: 1.6783 Validation Accuracy: 0.7292
# Time taken for 1 epoch: 72.15640544891357 secs
#
# Epoch 86 Batch 0 Loss 1.0861 Accuracy 0.6022
# Epoch 86 Batch 100 Loss 1.1397 Accuracy 0.6026
# Epoch 86 Batch 200 Loss 1.1508 Accuracy 0.6029
# Epoch 86 Batch 300 Loss 1.1847 Accuracy 0.6032
# Epoch 86 Batch 400 Loss 1.2240 Accuracy 0.6034
# Epoch 86 Batch 500 Loss 1.2543 Accuracy 0.6037
# Epoch 86 Batch 600 Loss 1.2865 Accuracy 0.6040
# Epoch 86 Loss 1.3146 Accuracy 0.6042
# Validation Loss: 1.6653 Validation Accuracy: 0.7313
# Time taken for 1 epoch: 71.21474528312683 secs
#
# Epoch 87 Batch 0 Loss 1.1464 Accuracy 0.6042
# Epoch 87 Batch 100 Loss 1.1061 Accuracy 0.6045
# Epoch 87 Batch 200 Loss 1.1386 Accuracy 0.6048
# Epoch 87 Batch 300 Loss 1.1751 Accuracy 0.6051
# Epoch 87 Batch 400 Loss 1.2138 Accuracy 0.6054
# Epoch 87 Batch 500 Loss 1.2527 Accuracy 0.6056
# Epoch 87 Batch 600 Loss 1.2838 Accuracy 0.6059
# Epoch 87 Loss 1.3085 Accuracy 0.6061
# Validation Loss: 1.6527 Validation Accuracy: 0.7333
# Time taken for 1 epoch: 71.22240948677063 secs
#
# Epoch 88 Batch 0 Loss 1.0143 Accuracy 0.6061
# Epoch 88 Batch 100 Loss 1.1108 Accuracy 0.6064
# Epoch 88 Batch 200 Loss 1.1471 Accuracy 0.6067
# Epoch 88 Batch 300 Loss 1.1790 Accuracy 0.6070
# Epoch 88 Batch 400 Loss 1.2169 Accuracy 0.6072
# Epoch 88 Batch 500 Loss 1.2423 Accuracy 0.6075
# Epoch 88 Batch 600 Loss 1.2738 Accuracy 0.6078
# Epoch 88 Loss 1.2994 Accuracy 0.6080
# Validation Loss: 1.6403 Validation Accuracy: 0.7353
# Time taken for 1 epoch: 71.2502281665802 secs
#
# Epoch 89 Batch 0 Loss 0.9651 Accuracy 0.6080
# Epoch 89 Batch 100 Loss 1.1132 Accuracy 0.6083
# Epoch 89 Batch 200 Loss 1.1403 Accuracy 0.6086
# Epoch 89 Batch 300 Loss 1.1790 Accuracy 0.6088
# Epoch 89 Batch 400 Loss 1.2101 Accuracy 0.6091
# Epoch 89 Batch 500 Loss 1.2390 Accuracy 0.6094
# Epoch 89 Batch 600 Loss 1.2654 Accuracy 0.6096
# Epoch 89 Loss 1.2878 Accuracy 0.6098
# Validation Loss: 1.6281 Validation Accuracy: 0.7372
# Time taken for 1 epoch: 71.18779516220093 secs
#
# Epoch 90 Batch 0 Loss 1.3360 Accuracy 0.6098
# Epoch 90 Batch 100 Loss 1.0744 Accuracy 0.6101
# Epoch 90 Batch 200 Loss 1.1272 Accuracy 0.6104
# Epoch 90 Batch 300 Loss 1.1616 Accuracy 0.6107
# Epoch 90 Batch 400 Loss 1.1941 Accuracy 0.6110
# Epoch 90 Batch 500 Loss 1.2230 Accuracy 0.6112
# Epoch 90 Batch 600 Loss 1.2593 Accuracy 0.6114
# Saving checkpoint for epoch 90 at checkpoints/ckpt-18
# Epoch 90 Loss 1.2848 Accuracy 0.6116
# Validation Loss: 1.6161 Validation Accuracy: 0.7392
# Time taken for 1 epoch: 72.02029037475586 secs
#
# Epoch 91 Batch 0 Loss 1.0968 Accuracy 0.6116
# Epoch 91 Batch 100 Loss 1.0896 Accuracy 0.6120
# Epoch 91 Batch 200 Loss 1.1160 Accuracy 0.6122
# Epoch 91 Batch 300 Loss 1.1485 Accuracy 0.6125
# Epoch 91 Batch 400 Loss 1.1813 Accuracy 0.6128
# Epoch 91 Batch 500 Loss 1.2126 Accuracy 0.6130
# Epoch 91 Batch 600 Loss 1.2456 Accuracy 0.6133
# Epoch 91 Loss 1.2724 Accuracy 0.6135
# Validation Loss: 1.6043 Validation Accuracy: 0.7411
# Time taken for 1 epoch: 71.36776566505432 secs
#
# Epoch 92 Batch 0 Loss 1.0425 Accuracy 0.6135
# Epoch 92 Batch 100 Loss 1.0762 Accuracy 0.6138
# Epoch 92 Batch 200 Loss 1.1124 Accuracy 0.6140
# Epoch 92 Batch 300 Loss 1.1512 Accuracy 0.6143
# Epoch 92 Batch 400 Loss 1.1816 Accuracy 0.6146
# Epoch 92 Batch 500 Loss 1.2091 Accuracy 0.6148
# Epoch 92 Batch 600 Loss 1.2429 Accuracy 0.6150
# Epoch 92 Loss 1.2678 Accuracy 0.6152
# Validation Loss: 1.5928 Validation Accuracy: 0.7429
# Time taken for 1 epoch: 71.36867547035217 secs
#
# Epoch 93 Batch 0 Loss 0.9751 Accuracy 0.6152
# Epoch 93 Batch 100 Loss 1.0679 Accuracy 0.6155
# Epoch 93 Batch 200 Loss 1.1135 Accuracy 0.6158
# Epoch 93 Batch 300 Loss 1.1432 Accuracy 0.6161
# Epoch 93 Batch 400 Loss 1.1841 Accuracy 0.6163
# Epoch 93 Batch 500 Loss 1.2138 Accuracy 0.6166
# Epoch 93 Batch 600 Loss 1.2445 Accuracy 0.6168
# Epoch 93 Loss 1.2714 Accuracy 0.6170
# Validation Loss: 1.5816 Validation Accuracy: 0.7447
# Time taken for 1 epoch: 71.2355740070343 secs
#
# Epoch 94 Batch 0 Loss 1.1190 Accuracy 0.6170
# Epoch 94 Batch 100 Loss 1.0598 Accuracy 0.6173
# Epoch 94 Batch 200 Loss 1.0991 Accuracy 0.6176
# Epoch 94 Batch 300 Loss 1.1266 Accuracy 0.6178
# Epoch 94 Batch 400 Loss 1.1606 Accuracy 0.6181
# Epoch 94 Batch 500 Loss 1.1948 Accuracy 0.6183
# Epoch 94 Batch 600 Loss 1.2280 Accuracy 0.6185
# Epoch 94 Loss 1.2530 Accuracy 0.6187
# Validation Loss: 1.5703 Validation Accuracy: 0.7465
# Time taken for 1 epoch: 71.1968605518341 secs
#
# Epoch 95 Batch 0 Loss 1.0407 Accuracy 0.6187
# Epoch 95 Batch 100 Loss 1.0547 Accuracy 0.6190
# Epoch 95 Batch 200 Loss 1.0962 Accuracy 0.6193
# Epoch 95 Batch 300 Loss 1.1203 Accuracy 0.6196
# Epoch 95 Batch 400 Loss 1.1601 Accuracy 0.6198
# Epoch 95 Batch 500 Loss 1.1907 Accuracy 0.6200
# Epoch 95 Batch 600 Loss 1.2202 Accuracy 0.6203
# Saving checkpoint for epoch 95 at checkpoints/ckpt-19
# Epoch 95 Loss 1.2409 Accuracy 0.6205
# Validation Loss: 1.5592 Validation Accuracy: 0.7483
# Time taken for 1 epoch: 72.10549664497375 secs
#
# Epoch 96 Batch 0 Loss 1.1540 Accuracy 0.6205
# Epoch 96 Batch 100 Loss 1.0562 Accuracy 0.6207
# Epoch 96 Batch 200 Loss 1.0873 Accuracy 0.6210
# Epoch 96 Batch 300 Loss 1.1171 Accuracy 0.6213
# Epoch 96 Batch 400 Loss 1.1520 Accuracy 0.6215
# Epoch 96 Batch 500 Loss 1.1815 Accuracy 0.6217
# Epoch 96 Batch 600 Loss 1.2145 Accuracy 0.6220
# Epoch 96 Loss 1.2438 Accuracy 0.6221
# Validation Loss: 1.5486 Validation Accuracy: 0.7500
# Time taken for 1 epoch: 71.24987816810608 secs
#
# Epoch 97 Batch 0 Loss 1.1210 Accuracy 0.6221
# Epoch 97 Batch 100 Loss 1.0472 Accuracy 0.6224
# Epoch 97 Batch 200 Loss 1.0711 Accuracy 0.6227
# Epoch 97 Batch 300 Loss 1.1118 Accuracy 0.6229
# Epoch 97 Batch 400 Loss 1.1462 Accuracy 0.6232
# Epoch 97 Batch 500 Loss 1.1746 Accuracy 0.6234
# Epoch 97 Batch 600 Loss 1.2104 Accuracy 0.6236
# Epoch 97 Loss 1.2381 Accuracy 0.6238
# Validation Loss: 1.5379 Validation Accuracy: 0.7518
# Time taken for 1 epoch: 71.23485827445984 secs
#
# Epoch 98 Batch 0 Loss 1.0143 Accuracy 0.6238
# Epoch 98 Batch 100 Loss 1.0812 Accuracy 0.6241
# Epoch 98 Batch 200 Loss 1.0904 Accuracy 0.6243
# Epoch 98 Batch 300 Loss 1.1109 Accuracy 0.6246
# Epoch 98 Batch 400 Loss 1.1402 Accuracy 0.6248
# Epoch 98 Batch 500 Loss 1.1763 Accuracy 0.6250
# Epoch 98 Batch 600 Loss 1.2082 Accuracy 0.6253
# Epoch 98 Loss 1.2352 Accuracy 0.6254
# Validation Loss: 1.5274 Validation Accuracy: 0.7535
# Time taken for 1 epoch: 71.53912901878357 secs
#
# Epoch 99 Batch 0 Loss 1.0806 Accuracy 0.6255
# Epoch 99 Batch 100 Loss 1.0166 Accuracy 0.6257
# Epoch 99 Batch 200 Loss 1.0604 Accuracy 0.6260
# Epoch 99 Batch 300 Loss 1.1024 Accuracy 0.6262
# Epoch 99 Batch 400 Loss 1.1392 Accuracy 0.6265
# Epoch 99 Batch 500 Loss 1.1702 Accuracy 0.6267
# Epoch 99 Batch 600 Loss 1.1988 Accuracy 0.6269
# Epoch 99 Loss 1.2256 Accuracy 0.6271
# Validation Loss: 1.5171 Validation Accuracy: 0.7551
# Time taken for 1 epoch: 71.22173523902893 secs
#
# Epoch 100 Batch 0 Loss 0.9400 Accuracy 0.6271
# Epoch 100 Batch 100 Loss 1.0359 Accuracy 0.6273
# Epoch 100 Batch 200 Loss 1.0700 Accuracy 0.6276
# Epoch 100 Batch 300 Loss 1.1039 Accuracy 0.6278
# Epoch 100 Batch 400 Loss 1.1328 Accuracy 0.6281
# Epoch 100 Batch 500 Loss 1.1636 Accuracy 0.6283
# Epoch 100 Batch 600 Loss 1.1931 Accuracy 0.6285
# Saving checkpoint for epoch 100 at checkpoints/ckpt-20
# Epoch 100 Loss 1.2194 Accuracy 0.6287
# Validation Loss: 1.5068 Validation Accuracy: 0.7568
# Time taken for 1 epoch: 72.01489663124084 secs
#
# Epoch 101 Batch 0 Loss 0.9551 Accuracy 0.6287
# Epoch 101 Batch 100 Loss 1.0264 Accuracy 0.6289
# Epoch 101 Batch 200 Loss 1.0639 Accuracy 0.6292
# Epoch 101 Batch 300 Loss 1.0983 Accuracy 0.6294
# Epoch 101 Batch 400 Loss 1.1283 Accuracy 0.6296
# Epoch 101 Batch 500 Loss 1.1622 Accuracy 0.6299
# Epoch 101 Batch 600 Loss 1.1932 Accuracy 0.6301
# Epoch 101 Loss 1.2188 Accuracy 0.6302
# Validation Loss: 1.4968 Validation Accuracy: 0.7584
# Time taken for 1 epoch: 71.24235892295837 secs
#
# Epoch 102 Batch 0 Loss 1.1987 Accuracy 0.6302
# Epoch 102 Batch 100 Loss 1.0281 Accuracy 0.6305
# ...
#
# Epoch 468 Batch 0 Loss 0.6380 Accuracy 0.8123
# Epoch 468 Batch 100 Loss 0.6615 Accuracy 0.8123
# Epoch 468 Batch 200 Loss 0.6727 Accuracy 0.8124
# Epoch 468 Batch 300 Loss 0.6962 Accuracy 0.8124
# Epoch 468 Batch 400 Loss 0.7155 Accuracy 0.8124
# Epoch 468 Batch 500 Loss 0.7343 Accuracy 0.8124
# Epoch 468 Batch 600 Loss 0.7553 Accuracy 0.8124
# Epoch 468 Loss 0.7719 Accuracy 0.8125
# Validation Loss: 0.6140 Validation Accuracy: 0.9095
# Time taken for 1 epoch: 71.24567580223083 secs
#
# Epoch 469 Batch 0 Loss 0.4879 Accuracy 0.8125
# Epoch 469 Batch 100 Loss 0.6453 Accuracy 0.8125
# Epoch 469 Batch 200 Loss 0.6732 Accuracy 0.8125
# Epoch 469 Batch 300 Loss 0.6929 Accuracy 0.8126
# Epoch 469 Batch 400 Loss 0.7141 Accuracy 0.8126
# Epoch 469 Batch 500 Loss 0.7354 Accuracy 0.8126
# Epoch 469 Batch 600 Loss 0.7558 Accuracy 0.8126
# Epoch 469 Loss 0.7740 Accuracy 0.8126
# Validation Loss: 0.6135 Validation Accuracy: 0.9096
# Time taken for 1 epoch: 71.24536514282227 secs
#
# Epoch 470 Batch 0 Loss 0.4265 Accuracy 0.8126
# Epoch 470 Batch 100 Loss 0.6506 Accuracy 0.8127
# Epoch 470 Batch 200 Loss 0.6709 Accuracy 0.8127
# Epoch 470 Batch 300 Loss 0.6916 Accuracy 0.8127
# Epoch 470 Batch 400 Loss 0.7130 Accuracy 0.8127
# Epoch 470 Batch 500 Loss 0.7361 Accuracy 0.8128
# Epoch 470 Batch 600 Loss 0.7526 Accuracy 0.8128
# Saving checkpoint for epoch 470 at checkpoints/ckpt-94
# Epoch 470 Loss 0.7710 Accuracy 0.8128
# Validation Loss: 0.6130 Validation Accuracy: 0.9097
# Time taken for 1 epoch: 72.0203320980072 secs
#
# Epoch 471 Batch 0 Loss 0.5141 Accuracy 0.8128
# Epoch 471 Batch 100 Loss 0.6372 Accuracy 0.8128
# Epoch 471 Batch 200 Loss 0.6561 Accuracy 0.8129
# Epoch 471 Batch 300 Loss 0.6832 Accuracy 0.8129
# Epoch 471 Batch 400 Loss 0.7058 Accuracy 0.8129
# Epoch 471 Batch 500 Loss 0.7277 Accuracy 0.8129
# Epoch 471 Batch 600 Loss 0.7493 Accuracy 0.8130
# Epoch 471 Loss 0.7675 Accuracy 0.8130
# Validation Loss: 0.6124 Validation Accuracy: 0.9098
# Time taken for 1 epoch: 71.23665308952332 secs
#
# Epoch 472 Batch 0 Loss 0.7472 Accuracy 0.8130
# Epoch 472 Batch 100 Loss 0.6421 Accuracy 0.8130
# Epoch 472 Batch 200 Loss 0.6671 Accuracy 0.8130
# Epoch 472 Batch 300 Loss 0.6964 Accuracy 0.8131
# Epoch 472 Batch 400 Loss 0.7150 Accuracy 0.8131
# Epoch 472 Batch 500 Loss 0.7373 Accuracy 0.8131
# Epoch 472 Batch 600 Loss 0.7540 Accuracy 0.8131
# Epoch 472 Loss 0.7699 Accuracy 0.8132
# Validation Loss: 0.6119 Validation Accuracy: 0.9099
# Time taken for 1 epoch: 71.24767780303955 secs
#
# Epoch 473 Batch 0 Loss 0.7816 Accuracy 0.8132
# Epoch 473 Batch 100 Loss 0.6554 Accuracy 0.8132
# Epoch 473 Batch 200 Loss 0.6726 Accuracy 0.8132
# Epoch 473 Batch 300 Loss 0.6923 Accuracy 0.8132
# Epoch 473 Batch 400 Loss 0.7126 Accuracy 0.8133
# Epoch 473 Batch 500 Loss 0.7307 Accuracy 0.8133
# Epoch 473 Batch 600 Loss 0.7476 Accuracy 0.8133
# Epoch 473 Loss 0.7648 Accuracy 0.8133
# Validation Loss: 0.6114 Validation Accuracy: 0.9100
# Time taken for 1 epoch: 71.23638129234314 secs
#
# Epoch 474 Batch 0 Loss 0.7640 Accuracy 0.8133
# Epoch 474 Batch 100 Loss 0.6364 Accuracy 0.8134
# Epoch 474 Batch 200 Loss 0.6628 Accuracy 0.8134
# Epoch 474 Batch 300 Loss 0.6785 Accuracy 0.8134
# Epoch 474 Batch 400 Loss 0.6984 Accuracy 0.8134
# Epoch 474 Batch 500 Loss 0.7209 Accuracy 0.8135
# Epoch 474 Batch 600 Loss 0.7459 Accuracy 0.8135
# Epoch 474 Loss 0.7672 Accuracy 0.8135
# Validation Loss: 0.6109 Validation Accuracy: 0.9101
# Time taken for 1 epoch: 71.2374575138092 secs
#
# Epoch 475 Batch 0 Loss 0.4542 Accuracy 0.8135
# Epoch 475 Batch 100 Loss 0.6549 Accuracy 0.8135
# Epoch 475 Batch 200 Loss 0.6721 Accuracy 0.8136
# Epoch 475 Batch 300 Loss 0.6888 Accuracy 0.8136
# Epoch 475 Batch 400 Loss 0.7103 Accuracy 0.8136
# Epoch 475 Batch 500 Loss 0.7330 Accuracy 0.8136
# Epoch 475 Batch 600 Loss 0.7532 Accuracy 0.8137
# Saving checkpoint for epoch 475 at checkpoints/ckpt-95
# Epoch 475 Loss 0.7736 Accuracy 0.8137
# Validation Loss: 0.6103 Validation Accuracy: 0.9102
# Time taken for 1 epoch: 72.02876830101013 secs
#
# Epoch 476 Batch 0 Loss 0.4828 Accuracy 0.8137
# Epoch 476 Batch 100 Loss 0.6348 Accuracy 0.8137
# Epoch 476 Batch 200 Loss 0.6597 Accuracy 0.8137
# Epoch 476 Batch 300 Loss 0.6818 Accuracy 0.8138
# Epoch 476 Batch 400 Loss 0.7028 Accuracy 0.8138
# Epoch 476 Batch 500 Loss 0.7250 Accuracy 0.8138
# Epoch 476 Batch 600 Loss 0.7461 Accuracy 0.8138
# Epoch 476 Loss 0.7673 Accuracy 0.8138
# Validation Loss: 0.6098 Validation Accuracy: 0.9103
# Time taken for 1 epoch: 71.20689487457275 secs
#
# Epoch 477 Batch 0 Loss 0.6272 Accuracy 0.8138
# Epoch 477 Batch 100 Loss 0.6461 Accuracy 0.8139
# Epoch 477 Batch 200 Loss 0.6670 Accuracy 0.8139
# Epoch 477 Batch 300 Loss 0.6903 Accuracy 0.8139
# Epoch 477 Batch 400 Loss 0.7087 Accuracy 0.8139
# Epoch 477 Batch 500 Loss 0.7268 Accuracy 0.8140
# Epoch 477 Batch 600 Loss 0.7499 Accuracy 0.8140
# Epoch 477 Loss 0.7682 Accuracy 0.8140
# Validation Loss: 0.6093 Validation Accuracy: 0.9104
# Time taken for 1 epoch: 71.20014953613281 secs
#
# Epoch 478 Batch 0 Loss 0.4993 Accuracy 0.8140
# Epoch 478 Batch 100 Loss 0.6437 Accuracy 0.8140
# Epoch 478 Batch 200 Loss 0.6776 Accuracy 0.8141
# Epoch 478 Batch 300 Loss 0.6981 Accuracy 0.8141
# Epoch 478 Batch 400 Loss 0.7126 Accuracy 0.8141
# Epoch 478 Batch 500 Loss 0.7295 Accuracy 0.8141
# Epoch 478 Batch 600 Loss 0.7495 Accuracy 0.8142
# Epoch 478 Loss 0.7654 Accuracy 0.8142
# Validation Loss: 0.6087 Validation Accuracy: 0.9105
# Time taken for 1 epoch: 71.21441006660461 secs
#
# Epoch 479 Batch 0 Loss 0.6237 Accuracy 0.8142
# Epoch 479 Batch 100 Loss 0.6499 Accuracy 0.8142
# Epoch 479 Batch 200 Loss 0.6677 Accuracy 0.8142
# Epoch 479 Batch 300 Loss 0.6794 Accuracy 0.8143
# Epoch 479 Batch 400 Loss 0.7041 Accuracy 0.8143
# Epoch 479 Batch 500 Loss 0.7231 Accuracy 0.8143
# Epoch 479 Batch 600 Loss 0.7465 Accuracy 0.8143
# Epoch 479 Loss 0.7651 Accuracy 0.8143
# Validation Loss: 0.6082 Validation Accuracy: 0.9106
# Time taken for 1 epoch: 71.21127676963806 secs
#
# Epoch 480 Batch 0 Loss 0.5757 Accuracy 0.8143
# Epoch 480 Batch 100 Loss 0.6542 Accuracy 0.8144
# Epoch 480 Batch 200 Loss 0.6690 Accuracy 0.8144
# Epoch 480 Batch 300 Loss 0.6899 Accuracy 0.8144
# Epoch 480 Batch 400 Loss 0.7081 Accuracy 0.8144
# Epoch 480 Batch 500 Loss 0.7286 Accuracy 0.8145
# Epoch 480 Batch 600 Loss 0.7504 Accuracy 0.8145
# Saving checkpoint for epoch 480 at checkpoints/ckpt-96
# Epoch 480 Loss 0.7634 Accuracy 0.8145
# Validation Loss: 0.6077 Validation Accuracy: 0.9107
# Time taken for 1 epoch: 71.97700095176697 secs
#
# Epoch 481 Batch 0 Loss 0.7523 Accuracy 0.8145
# Epoch 481 Batch 100 Loss 0.6480 Accuracy 0.8145
# Epoch 481 Batch 200 Loss 0.6609 Accuracy 0.8146
# Epoch 481 Batch 300 Loss 0.6861 Accuracy 0.8146
# Epoch 481 Batch 400 Loss 0.7040 Accuracy 0.8146
# Epoch 481 Batch 500 Loss 0.7236 Accuracy 0.8146
# Epoch 481 Batch 600 Loss 0.7449 Accuracy 0.8147
# Epoch 481 Loss 0.7597 Accuracy 0.8147
# Validation Loss: 0.6072 Validation Accuracy: 0.9108
# Time taken for 1 epoch: 71.21139740943909 secs
#
# Epoch 482 Batch 0 Loss 0.4960 Accuracy 0.8147
# Epoch 482 Batch 100 Loss 0.6381 Accuracy 0.8147
# Epoch 482 Batch 200 Loss 0.6640 Accuracy 0.8147
# Epoch 482 Batch 300 Loss 0.6813 Accuracy 0.8148
# Epoch 482 Batch 400 Loss 0.7029 Accuracy 0.8148
# Epoch 482 Batch 500 Loss 0.7255 Accuracy 0.8148
# Epoch 482 Batch 600 Loss 0.7489 Accuracy 0.8148
# Epoch 482 Loss 0.7671 Accuracy 0.8148
# Validation Loss: 0.6067 Validation Accuracy: 0.9109
# Time taken for 1 epoch: 71.19855117797852 secs
#
# Epoch 483 Batch 0 Loss 0.6757 Accuracy 0.8148
# Epoch 483 Batch 100 Loss 0.6466 Accuracy 0.8149
# Epoch 483 Batch 200 Loss 0.6637 Accuracy 0.8149
# Epoch 483 Batch 300 Loss 0.6823 Accuracy 0.8149
# Epoch 483 Batch 400 Loss 0.7067 Accuracy 0.8149
# Epoch 483 Batch 500 Loss 0.7257 Accuracy 0.8150
# Epoch 483 Batch 600 Loss 0.7467 Accuracy 0.8150
# Epoch 483 Loss 0.7635 Accuracy 0.8150
# Validation Loss: 0.6062 Validation Accuracy: 0.9110
# Time taken for 1 epoch: 71.2100260257721 secs
#
# Epoch 484 Batch 0 Loss 0.5826 Accuracy 0.8150
# Epoch 484 Batch 100 Loss 0.6226 Accuracy 0.8150
# Epoch 484 Batch 200 Loss 0.6578 Accuracy 0.8151
# Epoch 484 Batch 300 Loss 0.6774 Accuracy 0.8151
# Epoch 484 Batch 400 Loss 0.6984 Accuracy 0.8151
# Epoch 484 Batch 500 Loss 0.7218 Accuracy 0.8151
# Epoch 484 Batch 600 Loss 0.7458 Accuracy 0.8152
# Epoch 484 Loss 0.7656 Accuracy 0.8152
# Validation Loss: 0.6057 Validation Accuracy: 0.9111
# Time taken for 1 epoch: 71.19464945793152 secs
#
# Epoch 485 Batch 0 Loss 0.5029 Accuracy 0.8152
# Epoch 485 Batch 100 Loss 0.6343 Accuracy 0.8152
# Epoch 485 Batch 200 Loss 0.6629 Accuracy 0.8152
# Epoch 485 Batch 300 Loss 0.6822 Accuracy 0.8153
# Epoch 485 Batch 400 Loss 0.7003 Accuracy 0.8153
# Epoch 485 Batch 500 Loss 0.7209 Accuracy 0.8153
# Epoch 485 Batch 600 Loss 0.7438 Accuracy 0.8153
# Saving checkpoint for epoch 485 at checkpoints/ckpt-97
# Epoch 485 Loss 0.7636 Accuracy 0.8153
# Validation Loss: 0.6051 Validation Accuracy: 0.9112
# Time taken for 1 epoch: 71.9870958328247 secs
#
# Epoch 486 Batch 0 Loss 0.9221 Accuracy 0.8153
# Epoch 486 Batch 100 Loss 0.6504 Accuracy 0.8154
# Epoch 486 Batch 200 Loss 0.6641 Accuracy 0.8154
# Epoch 486 Batch 300 Loss 0.6870 Accuracy 0.8154
# Epoch 486 Batch 400 Loss 0.7060 Accuracy 0.8154
# Epoch 486 Batch 500 Loss 0.7270 Accuracy 0.8155
# Epoch 486 Batch 600 Loss 0.7462 Accuracy 0.8155
# Epoch 486 Loss 0.7639 Accuracy 0.8155
# Validation Loss: 0.6046 Validation Accuracy: 0.9113
# Time taken for 1 epoch: 71.22044897079468 secs
#
# Epoch 487 Batch 0 Loss 0.5888 Accuracy 0.8155
# Epoch 487 Batch 100 Loss 0.6382 Accuracy 0.8155
# Epoch 487 Batch 200 Loss 0.6607 Accuracy 0.8156
# Epoch 487 Batch 300 Loss 0.6807 Accuracy 0.8156
# Epoch 487 Batch 400 Loss 0.7008 Accuracy 0.8156
# Epoch 487 Batch 500 Loss 0.7204 Accuracy 0.8156
# Epoch 487 Batch 600 Loss 0.7430 Accuracy 0.8157
# Epoch 487 Loss 0.7614 Accuracy 0.8157
# Validation Loss: 0.6041 Validation Accuracy: 0.9114
# Time taken for 1 epoch: 71.21649861335754 secs
#
# Epoch 488 Batch 0 Loss 0.6324 Accuracy 0.8157
# Epoch 488 Batch 100 Loss 0.6591 Accuracy 0.8157
# Epoch 488 Batch 200 Loss 0.6680 Accuracy 0.8157
# Epoch 488 Batch 300 Loss 0.6797 Accuracy 0.8157
# Epoch 488 Batch 400 Loss 0.7042 Accuracy 0.8158
# Epoch 488 Batch 500 Loss 0.7241 Accuracy 0.8158
# Epoch 488 Batch 600 Loss 0.7448 Accuracy 0.8158
# Epoch 488 Loss 0.7642 Accuracy 0.8158
# Validation Loss: 0.6036 Validation Accuracy: 0.9115
# Time taken for 1 epoch: 71.22933292388916 secs
#
# Epoch 489 Batch 0 Loss 0.5947 Accuracy 0.8158
# Epoch 489 Batch 100 Loss 0.6445 Accuracy 0.8159
# Epoch 489 Batch 200 Loss 0.6588 Accuracy 0.8159
# Epoch 489 Batch 300 Loss 0.6788 Accuracy 0.8159
# Epoch 489 Batch 400 Loss 0.7032 Accuracy 0.8159
# Epoch 489 Batch 500 Loss 0.7226 Accuracy 0.8160
# Epoch 489 Batch 600 Loss 0.7418 Accuracy 0.8160
# Epoch 489 Loss 0.7642 Accuracy 0.8160
# Validation Loss: 0.6031 Validation Accuracy: 0.9116
# Time taken for 1 epoch: 71.21043992042542 secs
#
# Epoch 490 Batch 0 Loss 0.6050 Accuracy 0.8160
# Epoch 490 Batch 100 Loss 0.6614 Accuracy 0.8160
# Epoch 490 Batch 200 Loss 0.6730 Accuracy 0.8160
# Epoch 490 Batch 300 Loss 0.6847 Accuracy 0.8161
# Epoch 490 Batch 400 Loss 0.7055 Accuracy 0.8161
# Epoch 490 Batch 500 Loss 0.7264 Accuracy 0.8161
# Epoch 490 Batch 600 Loss 0.7472 Accuracy 0.8161
# Saving checkpoint for epoch 490 at checkpoints/ckpt-98
# Epoch 490 Loss 0.7668 Accuracy 0.8162
# Validation Loss: 0.6026 Validation Accuracy: 0.9117
# Time taken for 1 epoch: 71.96475315093994 secs
#
# Epoch 491 Batch 0 Loss 0.6095 Accuracy 0.8162
# Epoch 491 Batch 100 Loss 0.6364 Accuracy 0.8162
# Epoch 491 Batch 200 Loss 0.6591 Accuracy 0.8162
# Epoch 491 Batch 300 Loss 0.6814 Accuracy 0.8162
# Epoch 491 Batch 400 Loss 0.6988 Accuracy 0.8163
# Epoch 491 Batch 500 Loss 0.7199 Accuracy 0.8163
# Epoch 491 Batch 600 Loss 0.7397 Accuracy 0.8163
# Epoch 491 Loss 0.7570 Accuracy 0.8163
# Validation Loss: 0.6020 Validation Accuracy: 0.9118
# Time taken for 1 epoch: 71.21007299423218 secs
#
# Epoch 492 Batch 0 Loss 0.6028 Accuracy 0.8163
# Epoch 492 Batch 100 Loss 0.6360 Accuracy 0.8163
# Epoch 492 Batch 200 Loss 0.6561 Accuracy 0.8164
# Epoch 492 Batch 300 Loss 0.6795 Accuracy 0.8164
# Epoch 492 Batch 400 Loss 0.7057 Accuracy 0.8164
# Epoch 492 Batch 500 Loss 0.7285 Accuracy 0.8164
# Epoch 492 Batch 600 Loss 0.7461 Accuracy 0.8165
# Epoch 492 Loss 0.7632 Accuracy 0.8165
# Validation Loss: 0.6015 Validation Accuracy: 0.9119
# Time taken for 1 epoch: 71.21618151664734 secs
#
# Epoch 493 Batch 0 Loss 0.5978 Accuracy 0.8165
# Epoch 493 Batch 100 Loss 0.6428 Accuracy 0.8165
# Epoch 493 Batch 200 Loss 0.6611 Accuracy 0.8165
# Epoch 493 Batch 300 Loss 0.6777 Accuracy 0.8166
# Epoch 493 Batch 400 Loss 0.7019 Accuracy 0.8166
# Epoch 493 Batch 500 Loss 0.7249 Accuracy 0.8166
# Epoch 493 Batch 600 Loss 0.7475 Accuracy 0.8166
# Epoch 493 Loss 0.7635 Accuracy 0.8166
# Validation Loss: 0.6010 Validation Accuracy: 0.9120
# Time taken for 1 epoch: 71.21951532363892 secs
#
# Epoch 494 Batch 0 Loss 0.6610 Accuracy 0.8166
# Epoch 494 Batch 100 Loss 0.6302 Accuracy 0.8167
# Epoch 494 Batch 200 Loss 0.6576 Accuracy 0.8167
# Epoch 494 Batch 300 Loss 0.6801 Accuracy 0.8167
# Epoch 494 Batch 400 Loss 0.6998 Accuracy 0.8167
# Epoch 494 Batch 500 Loss 0.7224 Accuracy 0.8168
# Epoch 494 Batch 600 Loss 0.7450 Accuracy 0.8168
# Epoch 494 Loss 0.7637 Accuracy 0.8168
# Validation Loss: 0.6005 Validation Accuracy: 0.9121
# Time taken for 1 epoch: 71.22041654586792 secs
#
# Epoch 495 Batch 0 Loss 0.6240 Accuracy 0.8168
# Epoch 495 Batch 100 Loss 0.6387 Accuracy 0.8168
# Epoch 495 Batch 200 Loss 0.6620 Accuracy 0.8169
# Epoch 495 Batch 300 Loss 0.6818 Accuracy 0.8169
# Epoch 495 Batch 400 Loss 0.7030 Accuracy 0.8169
# Epoch 495 Batch 500 Loss 0.7238 Accuracy 0.8169
# Epoch 495 Batch 600 Loss 0.7465 Accuracy 0.8169
# Saving checkpoint for epoch 495 at checkpoints/ckpt-99
# Epoch 495 Loss 0.7640 Accuracy 0.8170
# Validation Loss: 0.6000 Validation Accuracy: 0.9122
# Time taken for 1 epoch: 72.03372192382812 secs
#
# Epoch 496 Batch 0 Loss 0.4818 Accuracy 0.8170
# Epoch 496 Batch 100 Loss 0.6332 Accuracy 0.8170
# Epoch 496 Batch 200 Loss 0.6571 Accuracy 0.8170
# Epoch 496 Batch 300 Loss 0.6780 Accuracy 0.8170
# Epoch 496 Batch 400 Loss 0.6978 Accuracy 0.8171
# Epoch 496 Batch 500 Loss 0.7179 Accuracy 0.8171
# Epoch 496 Batch 600 Loss 0.7380 Accuracy 0.8171
# Epoch 496 Loss 0.7570 Accuracy 0.8171
# Validation Loss: 0.5996 Validation Accuracy: 0.9122
# Time taken for 1 epoch: 71.20212292671204 secs
#
# Epoch 497 Batch 0 Loss 0.6334 Accuracy 0.8171
# Epoch 497 Batch 100 Loss 0.6479 Accuracy 0.8171
# Epoch 497 Batch 200 Loss 0.6508 Accuracy 0.8172
# Epoch 497 Batch 300 Loss 0.6756 Accuracy 0.8172
# Epoch 497 Batch 400 Loss 0.6940 Accuracy 0.8172
# Epoch 497 Batch 500 Loss 0.7156 Accuracy 0.8172
# Epoch 497 Batch 600 Loss 0.7377 Accuracy 0.8173
# Epoch 497 Loss 0.7599 Accuracy 0.8173
# Validation Loss: 0.5991 Validation Accuracy: 0.9123
# Time taken for 1 epoch: 71.20763230323792 secs
#
# Epoch 498 Batch 0 Loss 0.6493 Accuracy 0.8173
# Epoch 498 Batch 100 Loss 0.6498 Accuracy 0.8173
# Epoch 498 Batch 200 Loss 0.6654 Accuracy 0.8173
# Epoch 498 Batch 300 Loss 0.6874 Accuracy 0.8174
# Epoch 498 Batch 400 Loss 0.7040 Accuracy 0.8174
# Epoch 498 Batch 500 Loss 0.7265 Accuracy 0.8174
# Epoch 498 Batch 600 Loss 0.7462 Accuracy 0.8174
# Epoch 498 Loss 0.7642 Accuracy 0.8174
# Validation Loss: 0.5986 Validation Accuracy: 0.9124
# Time taken for 1 epoch: 71.23334407806396 secs
#
# Epoch 499 Batch 0 Loss 0.6378 Accuracy 0.8174
# Epoch 499 Batch 100 Loss 0.6387 Accuracy 0.8175
# Epoch 499 Batch 200 Loss 0.6623 Accuracy 0.8175
# Epoch 499 Batch 300 Loss 0.6750 Accuracy 0.8175
# Epoch 499 Batch 400 Loss 0.6981 Accuracy 0.8175
# Epoch 499 Batch 500 Loss 0.7233 Accuracy 0.8176
# Epoch 499 Batch 600 Loss 0.7439 Accuracy 0.8176
# Epoch 499 Loss 0.7616 Accuracy 0.8176
# Validation Loss: 0.5981 Validation Accuracy: 0.9125
# Time taken for 1 epoch: 71.20947813987732 secs
#
# Epoch 500 Batch 0 Loss 0.7893 Accuracy 0.8176
# Epoch 500 Batch 100 Loss 0.6379 Accuracy 0.8176
# Epoch 500 Batch 200 Loss 0.6550 Accuracy 0.8176
# Epoch 500 Batch 300 Loss 0.6809 Accuracy 0.8177
# Epoch 500 Batch 400 Loss 0.7009 Accuracy 0.8177
# Epoch 500 Batch 500 Loss 0.7208 Accuracy 0.8177
# Epoch 500 Batch 600 Loss 0.7407 Accuracy 0.8177
# Saving checkpoint for epoch 500 at checkpoints/ckpt-100
# Epoch 500 Loss 0.7577 Accuracy 0.8178
# Validation Loss: 0.5976 Validation Accuracy: 0.9126
# Time taken for 1 epoch: 71.97241878509521 secs

# %%
plt.plot(range(EPOCHS), train_loss_values, label='Training Loss')
plt.plot(range(EPOCHS), val_loss_values, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
plt.plot(range(EPOCHS), train_accuracy_values, label='Training Accuracy')
plt.plot(range(EPOCHS),val_accuracy_values,label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acuuracy')
plt.title('Accuracy Curve')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def evaluate(input_article):
    input_article = article_tokenizer.texts_to_sequences([input_article])
    input_article = tf.keras.preprocessing.sequence.pad_sequences(input_article, maxlen=ENCODER_LEN,
                                                                   padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_article[0], 0)

    decoder_input = [summary_tokenizer.word_index['<sos>']]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(DECODER_LEN):
        enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(encoder_input, output)

        predictions, attention_weights = transformer(
            encoder_input,
            output,
            False,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )

        predictions = predictions[: ,-1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index['<eos>']:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def summarize(input_article):
    summarized = evaluate(input_article=input_article)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)
    return summary_tokenizer.sequences_to_texts(summarized)[0]

# %%
article[5]

# %%
print("Real Headline : ", summary[5][5:-5],"\n Predicted Summary : ", summarize(article[5]))

# %%
print("Real Headline : ", summary[16][5:-5],"\nPredicted Summary : ", summarize(article[16]))

# %%
article[23]

# %%
print("Real Headline : ", summary[23][5:-5],"\nPredicted Summary : ", summarize(article[23]))

# %%
article = '<SOS>World leaders from more than 190 countries have converged on Geneva for a crucial summit aimed at addressing the growing climate crisis. The Climate Action Summit, organized by the United Nations, is a response to the alarming increase in extreme weather events, rising sea levels, and the urgent need to reduce greenhouse gas emissions.<EOS>'

# %%
print(summarize(article))
